# %% [markdown]
# # Import Libraries and Read Datasets

# %%
# !pip install langchain
# !pip install sentence-transformers
# !pip install faiss-cpu
# !pip install langchainhub
# !pip install tqdm
# !pip install --upgrade pip
# !pip install farm-haystack[colab,inference]#==1.22
# Out:
# Requirement already satisfied: langchain in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (0.0.345)
# Requirement already satisfied: PyYAML>=5.3 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from langchain) (2.0.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from langchain) (3.9.1)
# Requirement already satisfied: anyio<4.0 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from langchain) (3.7.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from langchain) (0.6.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-core<0.1,>=0.0.9 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from langchain) (0.0.9)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.63 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from langchain) (0.0.69)
# Requirement already satisfied: numpy<2,>=1 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from langchain) (1.26.2)
# Requirement already satisfied: pydantic<3,>=1 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from langchain) (1.10.13)
# Requirement already satisfied: requests<3,>=2 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from anyio<4.0->langchain) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from anyio<4.0->langchain) (1.3.0)
# Requirement already satisfied: exceptiongroup in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from anyio<4.0->langchain) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2023.11.17)
# Requirement already satisfied: packaging>=17.0 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.7,>=0.5.7->langchain) (23.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: sentence-transformers in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from sentence-transformers) (4.34.1)
# Requirement already satisfied: tqdm in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from sentence-transformers) (2.1.1)
# Requirement already satisfied: torchvision in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from sentence-transformers) (0.16.1)
# Requirement already satisfied: numpy in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from sentence-transformers) (1.26.2)
# Requirement already satisfied: scikit-learn in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from sentence-transformers) (1.3.2)
# Requirement already satisfied: scipy in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: nltk in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from sentence-transformers) (0.17.3)
# Requirement already satisfied: filelock in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.10.0)
# Requirement already satisfied: requests in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.8.0)
# Requirement already satisfied: packaging>=20.9 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.10.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.4.1)
# Requirement already satisfied: click in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from torchvision->sentence-transformers) (9.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: faiss-cpu in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (1.7.4)
# Requirement already satisfied: langchainhub in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (0.1.14)
# Requirement already satisfied: requests<3,>=2 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from langchainhub) (2.31.0)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from langchainhub) (2.31.0.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from requests<3,>=2->langchainhub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from requests<3,>=2->langchainhub) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from requests<3,>=2->langchainhub) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (from requests<3,>=2->langchainhub) (2023.11.17)
# Requirement already satisfied: tqdm in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (4.66.1)
# Requirement already satisfied: pip in /Users/kon/triviaqa/.venv/lib/python3.9/site-packages (23.3.1)
# zsh:1: no matches found: farm-haystack[colab,inference]#==1.22

# %%
import string
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings

def retrieve_wiki_headers_and_paragraphs(context, langchain=False):
  data = context.split("\n\n")
  current_header = "General"
  results = []

  for part in data:
    if part[:-1] not in string.punctuation and len(part.split()) < 10:
      current_header = part
    else:
      results.append((current_header, part))

  if not langchain:
    return results
  else:
    return [item[0] + " - " + item[1] for item in results]

# %%
def rag_get_context(question, context, log=False):
    paragraphs = retrieve_wiki_headers_and_paragraphs(context, langchain=True)
    vectorstore = FAISS.from_texts(texts=paragraphs, embedding=HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2"))
    retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": 1}, return_parents=False)
    par = retriever.get_relevant_documents(question)

    return par[0].page_content

# %%
import json
import os
def convert_to_json(input, output_filename):
# Convert the evaluation set to the desired format
    data = []
    for item in input:
        answer = {
            "Aliases": item["answer"]["aliases"],
            "MatchedWikiEntityName": item["answer"]["matched_wiki_entity_name"],
            "NormalizedAliases": item["answer"]["normalized_aliases"],
            "NormalizedMatchedWikiEntityName": item["answer"]["normalized_matched_wiki_entity_name"],
            "NormalizedValue": item["answer"]["normalized_value"],
            "Type": item["answer"]["type"],
            "Value": item["answer"]["value"],
        }
        entity_pages = [
            {
                "DocSource": item["entity_pages"]["doc_source"][index],
                "Filename": item["entity_pages"]["filename"][index],
                "Title": item["entity_pages"]["title"][index],
            }
            for index in range(len(item["entity_pages"]["filename"]))
        ]
        question = item["question"]
        question_id = item["question_id"]
        question_source = item["question_source"]
        search_results = []
        data_item = {
            "Answer": answer,
            "EntityPages": entity_pages,
            "Question": question,
            "QuestionId": question_id,
            "QuestionSource": question_source,
            "SearchResults": search_results,
        }
        data.append(data_item)
    
    output = {
        "Data": data,
        "Domain": "Wikipedia",
        "VerifiedEval": False,
        "Version": 1.0,
    }
    
    # Write the output to a JSON file
    if not os.path.exists("triviaqa/sets"):
        os.makedirs("triviaqa/sets")
    
    with open(f"triviaqa/sets/{output_filename}.json", "w") as f:
        json.dump(output, f)
        
    return output

# %%
# # Script based on https://github.com/mandarjoshi90/triviaqa/blob/master/utils/convert_to_squad_format.py
# # We include functions that are modified from https://github.com/mandarjoshi90/triviaqa/tree/master/utils
# # cite: https://github.com/mandarjoshi90/triviaqa/

import os, re, json, nltk
from tqdm import tqdm
from langchain.document_loaders.telegram import text_to_docs


def add_triple_data(datum, page, domain):
    qad = {'Source': domain}
    for key in ['QuestionId', 'Question', 'Answer']:
        qad[key] = datum[key]
    for key in page:
        qad[key] = page[key]
    return qad


def get_qad_triples(data):
    qad_triples = []
    for datum in data['Data']:
        for key in ['EntityPages', 'SearchResults']:
            for page in datum.get(key, []):
                qad = add_triple_data(datum, page, key)
                qad_triples.append(qad)
    return qad_triples

# from utils.utils import get_file_contents

def get_file_contents(filename, encoding='utf-8'):
    with open(filename, encoding=encoding) as f:
        content = f.read()
    return content

# from utils.dataset_utils import read_triviaqa_data, get_question_doc_string

def read_triviaqa_data(qajson):
    data = read_json(qajson)
    # read only documents and questions that are a part of clean data set
    if data['VerifiedEval']:
        clean_data = []
        for datum in data['Data']:
            if datum['QuestionPartOfVerifiedEval']:
                if data['Domain'] == 'Web':
                    datum = read_clean_part(datum)
                clean_data.append(datum)
        data['Data'] = clean_data
    return data

def get_question_doc_string(qid, doc_name):
    return '{}--{}'.format(qid, doc_name)

def read_clean_part(datum):
    for key in ['EntityPages', 'SearchResults']:
        new_page_list = []
        for page in datum.get(key, []):
            if page['DocPartOfVerifiedEval']:
                new_page_list.append(page)
        datum[key] = new_page_list
    assert len(datum['EntityPages']) + len(datum['SearchResults']) > 0
    return datum

def read_json(filename, encoding='utf-8'):
    contents = get_file_contents(filename, encoding=encoding)
    return json.loads(contents)

def select_relevant_portion(text):
    paras = text.split('\n')
    selected = []
    done = False
    for para in paras:
        sents = sent_tokenize.tokenize(para)
        for sent in sents:
            words = nltk.word_tokenize(sent)
            for word in words:
                selected.append(word)
                if len(selected) >= 800:
                    done = True
                    break
            if done:
                break
        if done:
            break
        selected.append('\n')
    st = ' '.join(selected).strip()
    return st


#-------------------------------------------------------



def answer_index_in_document(answer, document):
    answer_list = answer['Aliases'] + answer['NormalizedAliases']
    for answer_string_in_doc in answer_list:
        index = document.find(answer_string_in_doc)
        if index != -1:
            return answer_string_in_doc, index
    return answer['NormalizedValue'], -1



def triviaqa_to_squad_format(triviaqa_file, data_dir, output_file):
    processed_question_ids = set()
    triviaqa_json = read_triviaqa_data(triviaqa_file)
    qad_triples = get_qad_triples(triviaqa_json)

    def generate_data():
        for triviaqa_example in tqdm(qad_triples, desc="Processing QAD Triples"):
            question_text = triviaqa_example['Question']
            if triviaqa_example['QuestionId'] in processed_question_ids:
                continue
            processed_question_ids.add(triviaqa_example['QuestionId'])
            
            # Remove text between square brackets
            text = re.sub(r'\[.*?\]', '',get_file_contents(os.path.join(data_dir, triviaqa_example['Filename']), encoding='utf-8'))
            # Remove links with http/https
            text = re.sub(r'https?://\S+', '', text)
            
            context_str = select_relevant_portion(text)
            
            # context = rag_get_context(question_text, text, log=True)
            # if context:
            #     context_str = f'{context[0][0]}\n{context[0][1]}'
            #     print(f"PARAGRAPH: {context_str}")
            # else:
            #     context_str=""
            #     print("No Context")
            
            para = {'context': context_str, 'qas': [{'question': question_text, 'answers': []}]}
            data = {'paragraphs': [para]}
            qa = para['qas'][0]
            qa['id'] = get_question_doc_string(triviaqa_example['QuestionId'], triviaqa_example['Filename'])
            qa['is_impossible'] = True
            ans_string, index = answer_index_in_document(triviaqa_example['Answer'], context_str)

            if index != -1:
                qa['answers'].append({'text': ans_string, 'answer_start': index})
                qa['is_impossible'] = False
        
            
            yield data

    triviaqa_as_squad = {'data': list(generate_data()), 'version': '2.0'}

    with open(output_file, 'w', encoding='utf-8') as outfile:
        json.dump(triviaqa_as_squad, outfile, indent=2, sort_keys=True, ensure_ascii=False)

# Clear unused variables
    del triviaqa_json
    del triviaqa_as_squad
    del qad_triples

sent_tokenize = nltk.data.load('tokenizers/punkt/english.pickle')

# %% [markdown]
# Get the trivia QA dataset

# %%
# !cd BERT/
# !brew install wget
# !wget "https://nlp.cs.washington.edu/triviaqa/data/triviaqa-rc.tar.gz"
# Out:
# Running `brew update --auto-update`...
# ==> Downloading https://ghcr.io/v2/homebrew/portable-ruby/portable-ruby/blobs/sha256:d783cbeb6e6ef0d71c0b442317b54554370decd6fac66bf2d4938c07a63f67be
# ######################################################################### 100.0%                2.3%
# ==> Pouring portable-ruby-3.1.4.arm64_big_sur.bottle.tar.gz
# ==> Auto-updated Homebrew!
# Updated 3 taps (homebrew/services, homebrew/core and homebrew/cask).
# ==> New Formulae
# abi3audit                                pmix
# action-validator                         postgresql@16
# ain                                      presenterm
# ali                                      pter
# amass                                    python-abseil
# ansible@8                                python-anytree
# apkleaks                                 python-argcomplete
# appstream                                python-asn1crypto
# argc                                     python-attrs
# asitop                                   python-boto3
# auditwheel                               python-botocore
# authz0                                   python-brotli
# awscli-local                             python-cachetools
# badkeys                                  python-chardet
# bandicoot                                python-charset-normalizer
# bao                                      python-cli-helpers
# bashunit                                 python-colorama
# biodiff                                  python-configargparse
# biome                                    python-configobj
# bkcrack                                  python-cycler
# blake3                                   python-dateutil
# bob                                      python-dicttoxml
# bomber                                   python-distlib
# bounceback                               python-distro
# bozohttpd                                python-docopt
# build2                                   python-filelock
# caracal                                  python-gdbm@3.12
# cargo-sweep                              python-hatch-fancy-pypi-readme
# cariddi                                  python-hatch-vcs
# certgraph                                python-hatchling
# certsync                                 python-idna
# cf2tf                                    python-jinja
# cfripper                                 python-jmespath
# chainloop-cli                            python-json5
# chainsaw                                 python-kiwisolver
# changie                                  python-magic
# cherrybomb                               python-mako
# chisel-tunnel                            python-markdown-it-py
# cidr                                     python-matplotlib
# cliam                                    python-mdurl
# cloudsplaining                           python-mpmath
# colmap                                   python-msgpack
# crunchy-cli                              python-networkx
# csprecon                                 python-oauthlib
# daktilo                                  python-openapi3
# dalfox                                   python-pathspec
# dcp                                      python-pbr
# der-ascii                                python-platformdirs
# dezoomify-rs                             python-pluggy
# dicebear                                 python-ply
# diffoci                                  python-prompt-toolkit
# direwolf                                 python-psutil
# dockerfile-language-server               python-regex
# dockly                                   python-requests
# doppler                                  python-requests-oauthlib
# dovi_tool                                python-rich
# drogon                                   python-s3transfer
# eatmemory                                python-setuptools
# faircamp                                 python-setuptools-scm
# favirecon                                python-sympy
# flyscrape                                python-termcolor
# frozen                                   python-tk@3.12
# gdrive@2                                 python-trove-classifiers
# geoip2fast                               python-urllib3
# ggshield                                 python-wcwidth
# ghc@9.4                                  python-websocket-client
# ghc@9.6                                  python-xlsxwriter
# git-mediate                              python@3.12
# gitsign                                  qalculate-qt
# gittuf                                   qbittorrent-cli
# glbinding@2                              rapidfuzz-cpp
# goresym                                  raven
# gossip                                   rdap
# gotpm                                    redress
# gptline                                  redwax-tool
# graphqlviz                               reflex
# haiti                                    regclient
# helidon                                  rekor-cli
# immer                                    retire
# incus                                    retry
# instaloader                              richgo
# intercept                                ruler
# invoice                                  saf-cli
# iocextract                               scarb
# jprq                                     scikit-image
# jupyter-r                                scilla
# karmadactl                               scoutsuite
# kew                                      shell2http
# lager                                    shellspec
# ldeep                                    sigma-cli
# libconfini                               signmykey
# libcyaml                                 sigstore
# libdicom                                 skate
# libdpp                                   sloth
# libimobiledevice-glue                    smlfmt
# libjuice                                 snakeviz
# libmapper                                snyk-cli
# libnghttp3                               solo2-cli
# libsail                                  spglib
# llvm@16                                  spicetify-cli
# mariadb@11.1                             spidermonkey@91
# mediamtx                                 sqlfmt
# memray                                   sqlsmith
# mentat                                   squealer
# minder                                   squiid
# modsecurity                              ssh-mitm
# modsurfer                                sshportal
# netlistsvg                               tailspin
# node@20                                  tailwindcss
# noir                                     telegram-downloader
# numbat                                   terraform-local
# nvimpager                                texttest
# ocaml@4                                  three-body
# onionprobe                               tlrc
# open-simh                                trafilatura
# opentofu                                 uffizzi
# orbuculum                                uvicorn
# orcania                                  vet
# orogene                                  virtctl
# osctrl-cli                               vulsio-gost
# oslo                                     web-ext
# pan                                      whisper-cpp
# patat                                    witness
# patch-package                            wormhole-william
# pciutils                                 xeol
# pdfalyzer                                xnvme
# pdfrip                                   yatas
# perl-xml-parser                          yder
# php@8.2                                  zix
# phylum-cli                               zug
# ==> New Casks
# affine                                   mediamate
# amie                                     metamer
# anka-build-cloud-controller              mindmac
# anka-build-cloud-registry                mitmproxy
# ava                                      modrinth
# batchoutput-pdf                          music-decoy
# batteryboi                               mutedeck
# bezel                                    muyu
# brickstore                               navigraph-charts
# brightintosh                             navigraph-simlink
# btp                                      notes-better
# cardo-update                             nvs
# chainner                                 nx-studio
# clibor                                   october
# clinq                                    ok-json
# cloudnet                                 orka3
# codewhisperer                            ovito
# commandpost                              ovito-pro
# deskpad                                  paulxstretch
# deveco-studio                            playdate-mirror
# devtunnel                                proton-drive
# douyin-chat                              reqable
# dropbox-dash                             rode-central
# dropshelf                                routine
# ecodms-client                            rustrover
# effect-house                             screens-assist
# expo-orbit                               senabluetoothdevicemanager
# finbar                                   sf
# focusrite-control-2                      simplex
# fossa                                    songkong
# free-podcast-transcription               space-capsule
# garmin-basecamp                          spacedrive
# greenery                                 spundle
# gstreamer-development                    telegram-a
# gstreamer-runtime                        timemachinestatus
# hapigo                                   to-audio-converter
# hides                                    truhu
# hoppscotch                               tunetag
# hp-easy-admin                            twelite-stage
# jazz2-resurrection                       vimcal
# keymapp                                  wave
# kuaitie                                  wiso-steuer-2024
# libndi                                   writerside
# low-profile                              xliff-editor
# macgpt                                   xsplit-vcam
# mdb-accdb-viewer
#
# You have 11 outdated formulae installed.
#
# ==> Downloading https://ghcr.io/v2/homebrew/core/wget/manifests/1.21.4
# ######################################################################### 100.0%
# ==> Fetching dependencies for wget: libunistring and libidn2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/manifests/1.1
# ######################################################################### 100.0%
# ==> Fetching libunistring
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/blobs/sha256:c78e7
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libidn2/manifests/2.3.4_1-1
# ######################################################################### 100.0%
# ==> Fetching libidn2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libidn2/blobs/sha256:b044c66cc0
# ######################################################################### 100.0%
# ==> Fetching wget
# ==> Downloading https://ghcr.io/v2/homebrew/core/wget/blobs/sha256:c7b3fe54045aa
# ######################################################################### 100.0%
# ==> Installing dependencies for wget: libunistring and libidn2
# ==> Installing wget dependency: libunistring
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/manifests/1.1
# Already downloaded: /Users/kon/Library/Caches/Homebrew/downloads/a34801f1ad5800ba51b2b3951d82a913ccf0641982f86b02df2f0aa182535055--libunistring-1.1.bottle_manifest.json
# ==> Pouring libunistring--1.1.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libunistring/1.1: 56 files, 5.0MB
# ==> Installing wget dependency: libidn2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libidn2/manifests/2.3.4_1-1
# Already downloaded: /Users/kon/Library/Caches/Homebrew/downloads/03ad193177f4e7d05ee2ed19a455028cb5fbf7ea1a812d88f18f5e9e8b4a4d43--libidn2-2.3.4_1-1.bottle_manifest.json
# ==> Pouring libidn2--2.3.4_1.arm64_ventura.bottle.1.tar.gz
# 🍺  /opt/homebrew/Cellar/libidn2/2.3.4_1: 79 files, 1MB
# ==> Installing wget
# ==> Pouring wget--1.21.4.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/wget/1.21.4: 91 files, 4.4MB
# ==> Running `brew cleanup wget`...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> `brew cleanup` has not been run in the last 30 days, running now...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# Removing: /Users/kon/Library/Caches/Homebrew/autoconf--2.71... (944.1KB)
# Removing: /Users/kon/Library/Caches/Homebrew/gettext--0.21.1... (8.8MB)
# Removing: /Users/kon/Library/Caches/Homebrew/icu4c--73.2... (29.3MB)
# Removing: /Users/kon/Library/Caches/Homebrew/lz4--1.9.4... (251.0KB)
# Removing: /Users/kon/Library/Caches/Homebrew/m4--1.4.19... (255.7KB)
# Removing: /Users/kon/Library/Caches/Homebrew/mpdecimal--2.5.1... (538KB)
# Removing: /Users/kon/Library/Caches/Homebrew/openssl@3--3.1.2... (7.7MB)
# Removing: /Users/kon/Library/Caches/Homebrew/pkg-config--0.29.2_3... (236.8KB)
# Removing: /Users/kon/Library/Caches/Homebrew/readline--8.2.1... (573.8KB)
# Removing: /Users/kon/Library/Caches/Homebrew/xz--5.4.4... (660.5KB)
# Removing: /Users/kon/Library/Caches/Homebrew/python@3.11_bottle_manifest--3.11.4_1... (21.9KB)
# Removing: /Users/kon/Library/Caches/Homebrew/lz4_bottle_manifest--1.9.4... (8KB)
# Removing: /Users/kon/Library/Caches/Homebrew/openssl@3_bottle_manifest--3.1.1_1... (9KB)
# Removing: /Users/kon/Library/Caches/Homebrew/gettext_bottle_manifest--0.21.1... (10.8KB)
# Removing: /Users/kon/Library/Caches/Homebrew/readline_bottle_manifest--8.2.1... (8.6KB)
# Removing: /Users/kon/Library/Caches/Homebrew/krb5_bottle_manifest--1.21.1... (11.4KB)
# Removing: /Users/kon/Library/Caches/Homebrew/gmp--6.2.1_1... (1007.7KB)
# Removing: /Users/kon/Library/Caches/Homebrew/icu4c_bottle_manifest--73.2... (8.4KB)
# Removing: /Users/kon/Library/Caches/Homebrew/m4_bottle_manifest--1.4.19... (8.7KB)
# Removing: /Users/kon/Library/Caches/Homebrew/openssl@3_bottle_manifest--3.1.2-1... (8.8KB)
# Removing: /Users/kon/Library/Caches/Homebrew/pipenv_bottle_manifest--2023.7.11... (17.4KB)
# Removing: /Users/kon/Library/Caches/Homebrew/postgresql@15_bottle_manifest--15.3_2... (16.4KB)
# Removing: /Users/kon/Library/Caches/Homebrew/pyenv_bottle_manifest--2.3.22... (24.0KB)
# Removing: /Users/kon/Library/Caches/Homebrew/xz_bottle_manifest--5.4.3... (7.5KB)
# Removing: /Users/kon/Library/Caches/Homebrew/sqlite_bottle_manifest--3.42.0... (8.1KB)
# Removing: /Users/kon/Library/Caches/Homebrew/autoconf_bottle_manifest--2.71... (11.7KB)
# Removing: /Users/kon/Library/Caches/Homebrew/mpdecimal_bottle_manifest--2.5.1... (8.6KB)
# Removing: /Users/kon/Library/Caches/Homebrew/ca-certificates_bottle_manifest--2023-05-30... (7.3KB)
# Removing: /Users/kon/Library/Caches/Homebrew/pkg-config_bottle_manifest--0.29.2_3... (9.2KB)
# Removing: /Users/kon/Library/Caches/Homebrew/mpfr--4.2.0-p12... (1MB)
# Removing: /opt/homebrew/lib/python3.11/site-packages/__pycache__/appdirs.cpython-311.pyc... (28.9KB)
# Removing: /opt/homebrew/lib/python3.11/site-packages/__pycache__/findimports.cpython-311.pyc... (50.5KB)
# Removing: /opt/homebrew/lib/python3.11/site-packages/__pycache__/semver.cpython-311.pyc... (49.2KB)
# Removing: /opt/homebrew/lib/python3.11/site-packages/__pycache__/update_checker.cpython-311.pyc... (12.5KB)
# Removing: /opt/homebrew/lib/python3.11/site-packages/__pycache__/update_checker_test.cpython-311.pyc... (4.6KB)
# --2023-12-13 11:55:35--  https://nlp.cs.washington.edu/triviaqa/data/triviaqa-rc.tar.gz
# Resolving nlp.cs.washington.edu (nlp.cs.washington.edu)... 128.208.3.120
# Connecting to nlp.cs.washington.edu (nlp.cs.washington.edu)|128.208.3.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2665779500 (2.5G) [application/x-gzip]
# Saving to: ‘triviaqa-rc.tar.gz’
#
# triviaqa-rc.tar.gz   14%[=>                  ] 376.33M   574KB/s    eta 61m 39s^C

# %%
# %%bash
# mkdir ./triviaqa
# mkdir ./SQuadformatted
# tar -C ./triviaqa -zxf triviaqa-rc.tar.gz
# Out:
# mkdir: ./triviaqa: File exists
# mkdir: ./SQuadformatted: File exists

# %%
from datasets import load_dataset

trivia_qa_wikipedia = load_dataset('trivia_qa', name="rc.wikipedia")

training_split = trivia_qa_wikipedia["train"].train_test_split(shuffle=False, train_size=7900)
validation = convert_to_json(training_split["train"], output_filename="validation")
train = convert_to_json(training_split["test"], output_filename="training")

# %% [markdown]
# Convert

# %%
triviaqa_to_squad_format(triviaqa_file="triviaqa/sets/training.json", data_dir='triviaqa/evidence/wikipedia', output_file='SQuadformatted/triviaqa_train.json') # 7901 and following
# Out:
# Processing QAD Triples:   0%|          | 243/97386 [00:00<03:02, 532.30it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 triviaqa_to_squad_format(triviaqa_file="triviaqa/sets/training.json", data_dir='triviaqa/evidence/wikipedia', output_file='SQuadformatted/triviaqa_train.json') # 7901 and following
#
# Cell In[31], line 144, in triviaqa_to_squad_format(triviaqa_file, data_dir, output_file)
#     139             qa['is_impossible'] = False
#     142         yield data
# --> 144 triviaqa_as_squad = {'data': list(generate_data()), 'version': '2.0'}
#     146 with open(output_file, 'w', encoding='utf-8') as outfile:
#     147     json.dump(triviaqa_as_squad, outfile, indent=2, sort_keys=True, ensure_ascii=False)
#
# Cell In[31], line 135, in triviaqa_to_squad_format.<locals>.generate_data()
#     133 qa['id'] = get_question_doc_string(triviaqa_example['QuestionId'], triviaqa_example['Filename'])
#     134 qa['is_impossible'] = True
# --> 135 ans_string, index = answer_index_in_document(triviaqa_example['Answer'], context_str)
#     137 if index != -1:
#     138     qa['answers'].append({'text': ans_string, 'answer_start': index})
#
# Cell In[31], line 96, in answer_index_in_document(answer, document)
#      94 answer_list = answer['Aliases'] + answer['NormalizedAliases']
#      95 for answer_string_in_doc in answer_list:
# ---> 96     index = document.find(answer_string_in_doc)
#      97     if index != -1:
#      98         return answer_string_in_doc, index
#
# KeyboardInterrupt:

# %%
triviaqa_to_squad_format('triviaqa/sets/validation.json', 'triviaqa/evidence/wikipedia', 'SQuadformatted/triviaqa_validation.json')
# Out:
# Processing QAD Triples: 100%|██████████| 13261/13261 [00:23<00:00, 573.33it/s]

# %% [markdown]
# ### Training

# %%
from haystack.nodes import FARMReader

reader = FARMReader(model_name_or_path="distilbert-base-uncased-distilled-squad", use_gpu=True)
epochs = 1

# %%
import logging
from tqdm import tqdm

logging.basicConfig(format="%(levelname)s - %(name)s -  %(message)s", level=logging.WARNING)
logging.getLogger("haystack").setLevel(logging.WARNING)

reader.train(data_dir="SQuadformatted", train_filename="triviaqa_train.json", use_gpu=True, n_epochs=epochs, save_dir="my_model/")
#reader.train(data_dir="SQuadformatted", train_filename="triviaqa_train.json", dev_filename="triviaqa_validation.json", checkpoint_every=500, checkpoint_root_dir="checkpoints", evaluate_every=5000, use_gpu=False, n_epochs=epochs, save_dir="my_model/")# "{epoch}"  + "/")
# Out:
# Preprocessing dataset: 100%|██████████| 106/106 [01:07<00:00,  1.58 Dicts/s]
# Train epoch 0/0 (Cur. train loss: 2.7010):   0%|          | 62/33859 [00:38<5:49:16,  1.61it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 7
#       4 logging.basicConfig(format="%(levelname)s - %(name)s -  %(message)s", level=logging.WARNING)
#       5 logging.getLogger("haystack").setLevel(logging.WARNING)
# ----> 7 reader.train(data_dir="SQuadformatted", train_filename="triviaqa_train.json", use_gpu=True, n_epochs=epochs, save_dir="my_model/")
#       8 #reader.train(data_dir="SQuadformatted", train_filename="triviaqa_train.json", dev_filename="triviaqa_validation.json", checkpoint_every=500, checkpoint_root_dir="checkpoints", evaluate_every=5000, use_gpu=False, n_epochs=epochs, save_dir="my_model/")# "{epoch}"  + "/")
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/haystack/nodes/reader/farm.py:452, in FARMReader.train(self, data_dir, train_filename, dev_filename, test_filename, use_gpu, devices, batch_size, n_epochs, learning_rate, max_seq_len, warmup_proportion, dev_split, evaluate_every, save_dir, num_processes, use_amp, checkpoint_root_dir, checkpoint_every, checkpoints_to_keep, caching, cache_path, grad_acc_steps, early_stopping, max_query_length)
#     401 """
#     402 Fine-tune a model on a QA dataset. Options:
#     403 - Take a plain language model (e.g. `bert-base-cased`) and train it for QA (e.g. on SQuAD data)
#    (...)
#     449 :return: None
#     450 """
#     451 send_event(event_name="Training", event_properties={"class": self.__class__.__name__, "function_name": "train"})
# --> 452 return self._training_procedure(
#     453     data_dir=data_dir,
#     454     train_filename=train_filename,
#     455     dev_filename=dev_filename,
#     456     test_filename=test_filename,
#     457     use_gpu=use_gpu,
#     458     devices=devices,
#     459     batch_size=batch_size,
#     460     n_epochs=n_epochs,
#     461     learning_rate=learning_rate,
#     462     max_seq_len=max_seq_len,
#     463     warmup_proportion=warmup_proportion,
#     464     dev_split=dev_split,
#     465     evaluate_every=evaluate_every,
#     466     save_dir=save_dir,
#     467     num_processes=num_processes,
#     468     use_amp=use_amp,
#     469     checkpoint_root_dir=checkpoint_root_dir,
#     470     checkpoint_every=checkpoint_every,
#     471     checkpoints_to_keep=checkpoints_to_keep,
#     472     caching=caching,
#     473     cache_path=cache_path,
#     474     grad_acc_steps=grad_acc_steps,
#     475     early_stopping=early_stopping,
#     476     max_query_length=max_query_length,
#     477     distributed=False,
#     478 )
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/haystack/nodes/reader/farm.py:371, in FARMReader._training_procedure(self, data_dir, train_filename, dev_filename, test_filename, use_gpu, devices, batch_size, n_epochs, learning_rate, max_seq_len, warmup_proportion, dev_split, evaluate_every, save_dir, num_processes, use_amp, checkpoint_root_dir, checkpoint_every, checkpoints_to_keep, teacher_model, teacher_batch_size, caching, cache_path, distillation_loss_weight, distillation_loss, temperature, tinybert, processor, grad_acc_steps, early_stopping, distributed, doc_stride, max_query_length)
#     352     trainer = Trainer.create_or_load_checkpoint(
#     353         model=model,
#     354         optimizer=optimizer,
#    (...)
#     367         early_stopping=early_stopping,
#     368     )
#     370 # 5. Let it grow!
# --> 371 self.inferencer.model = trainer.train()
#     372 self.save(Path(save_dir))
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/haystack/modeling/training/base.py:217, in Trainer.train(self)
#     215 # Move batch of samples to device
#     216 batch = {key: batch[key].to(self.device) for key in batch}
# --> 217 loss = self.compute_loss(batch, step)
#     219 # Perform  evaluation
#     220 if (
#     221     self.evaluate_every != 0
#     222     and self.global_step % self.evaluate_every == 0
#     223     and self.global_step != 0
#     224     and self.local_rank in [0, -1]
#     225 ):
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/haystack/modeling/training/base.py:323, in Trainer.compute_loss(self, batch, step)
#     321     per_sample_loss = self.model.logits_to_loss(logits=logits, global_step=self.global_step, **batch)
#     322     loss = self.adjust_loss(per_sample_loss)
# --> 323 return self.backward_propagate(loss, step)
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/haystack/modeling/training/base.py:337, in Trainer.backward_propagate(self, loss, step)
#     335     self.scaler.unscale_(self.optimizer)
#     336     torch.nn.utils.clip_grad_norm_(self.model.parameters(), self.max_grad_norm)
# --> 337 self.scaler.step(self.optimizer)
#     338 self.scaler.update()
#     339 self.optimizer.zero_grad()
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:340, in GradScaler.step(self, optimizer, *args, **kwargs)
#     319 """
#     320 :meth:`step` carries out the following two operations:
#     321
#    (...)
#     337     Closure use is not currently supported.
#     338 """
#     339 if not self._enabled:
# --> 340     return optimizer.step(*args, **kwargs)
#     342 if "closure" in kwargs:
#     343     raise RuntimeError(
#     344         "Closure use is not currently supported if GradScaler is enabled."
#     345     )
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:68, in LRScheduler.__init__.<locals>.with_counter.<locals>.wrapper(*args, **kwargs)
#      66 instance._step_count += 1
#      67 wrapped = func.__get__(instance, cls)
# ---> 68 return wrapped(*args, **kwargs)
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/optim/optimizer.py:373, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     368         else:
#     369             raise RuntimeError(
#     370                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     371             )
# --> 373 out = func(*args, **kwargs)
#     374 self._optimizer_step_code()
#     376 # call optimizer step post hooks
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/optim/optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/optim/adamw.py:184, in AdamW.step(self, closure)
#     171     beta1, beta2 = group["betas"]
#     173     self._init_group(
#     174         group,
#     175         params_with_grad,
#    (...)
#     181         state_steps,
#     182     )
# --> 184     adamw(
#     185         params_with_grad,
#     186         grads,
#     187         exp_avgs,
#     188         exp_avg_sqs,
#     189         max_exp_avg_sqs,
#     190         state_steps,
#     191         amsgrad=amsgrad,
#     192         beta1=beta1,
#     193         beta2=beta2,
#     194         lr=group["lr"],
#     195         weight_decay=group["weight_decay"],
#     196         eps=group["eps"],
#     197         maximize=group["maximize"],
#     198         foreach=group["foreach"],
#     199         capturable=group["capturable"],
#     200         differentiable=group["differentiable"],
#     201         fused=group["fused"],
#     202         grad_scale=getattr(self, "grad_scale", None),
#     203         found_inf=getattr(self, "found_inf", None),
#     204     )
#     206 return loss
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/optim/adamw.py:335, in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     332 else:
#     333     func = _single_tensor_adamw
# --> 335 func(
#     336     params,
#     337     grads,
#     338     exp_avgs,
#     339     exp_avg_sqs,
#     340     max_exp_avg_sqs,
#     341     state_steps,
#     342     amsgrad=amsgrad,
#     343     beta1=beta1,
#     344     beta2=beta2,
#     345     lr=lr,
#     346     weight_decay=weight_decay,
#     347     eps=eps,
#     348     maximize=maximize,
#     349     capturable=capturable,
#     350     differentiable=differentiable,
#     351     grad_scale=grad_scale,
#     352     found_inf=found_inf,
#     353 )
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/optim/adamw.py:466, in _single_tensor_adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     463     else:
#     464         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
# --> 466     param.addcdiv_(exp_avg, denom, value=-step_size)
#     468 # Lastly, switch back to complex view
#     469 if amsgrad and torch.is_complex(params[i]):
#
# KeyboardInterrupt:

# %%
question=f"You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use one to two words or numbers maximum and keep the answer concise. question: {question}"

# %% [markdown]
# ## context-tools

# %%
from datasets import load_dataset
trivia_qa_wikipedia = load_dataset('trivia_qa', name="rc.wikipedia")
test = trivia_qa_wikipedia["validation"]

# %%
def build_context(item):
    texts = []
    for text in item["entity_pages"]["wiki_context"]:
      texts.append(text)

    context = " ".join(texts)
    return context

# %% [markdown]
# ## Prediction

# %%
from haystack.nodes import FARMReader
model_name="distilbert-base-uncased-distilled-squad"
reader = FARMReader(model_name_or_path=f"{model_name}", use_gpu=False)

# %%
import logging
import os, json
from tqdm import tqdm
from haystack.schema import Document
from haystack.nodes import BM25Retriever

predictions = {}
count=0
failed= []

logging.basicConfig(format="%(levelname)s - %(name)s -  %(message)s", level=logging.ERROR)

for entry in tqdm(test, desc="Processing Predictions"):
    try:
        context = build_context(entry)
        rag_context = rag_get_context(entry["question"], context, log=True)
        #print(rag_context)
        prediction = reader.predict(query=entry["question"], documents=[Document(rag_context)])
        predictions[entry['question_id']] = prediction['answers'][0].answer
        #print(f"question: {entry['question_id']}, answer: {prediction['answers'][0].answer}")
        #print("_"*25)
    except KeyboardInterrupt as error:
        json_string = json.dumps(predictions)
        if not os.path.exists("predictions"):
            os.makedirs("predictions")
        with open(f"predictions/validation_predictions_{model_name}.json", "w") as f:
            f.write(json_string)
        print("saved")
        raise error
    except Exception as error:
        print(f"Failure for question {entry['question_id']} ({type(error).__name__}: {error})")
        failed.append(entry['question_id'])
        
#print(f"FAILED: {failed}")
json_string = json.dumps(predictions)

if not os.path.exists("predictions"):
        os.makedirs("predictions")

with open(f"predictions/validation_predictions_{model_name}.json", "w") as f:
    f.write(json_string)
# Out:
# Processing Predictions:   0%|          | 0/7993 [00:00<?, ?it/s]
# Inferencing Samples:   0%|          | 0/1 [00:00<?, ? Batches/s]WARNING - haystack.modeling.model.language_model -  'segment_ids' is not None, but DistilBert does not use them. They will be ignored.
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.21 Batches/s]
# Processing Predictions:   0%|          | 1/7993 [00:01<3:12:21,  1.44s/it]
# Inferencing Samples:   0%|          | 0/1 [00:00<?, ? Batches/s]WARNING - haystack.modeling.model.language_model -  'segment_ids' is not None, but DistilBert does not use them. They will be ignored.
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 18.57 Batches/s]
# Processing Predictions:   0%|          | 2/7993 [00:03<3:48:43,  1.72s/it]
# Inferencing Samples:   0%|          | 0/1 [00:00<?, ? Batches/s]WARNING - haystack.modeling.model.language_model -  'segment_ids' is not None, but DistilBert does not use them. They will be ignored.
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.22 Batches/s]
# Processing Predictions:   0%|          | 3/7993 [00:03<2:23:24,  1.08s/it]
# Inferencing Samples:   0%|          | 0/1 [00:00<?, ? Batches/s]WARNING - haystack.modeling.model.language_model -  'segment_ids' is not None, but DistilBert does not use them. They will be ignored.
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.64 Batches/s]
# Processing Predictions:   0%|          | 4/7993 [00:04<2:13:24,  1.00s/it]
# Inferencing Samples:   0%|          | 0/1 [00:00<?, ? Batches/s]WARNING - haystack.modeling.model.language_model -  'segment_ids' is not None, but DistilBert does not use them. They will be ignored.
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 20.12 Batches/s]
# Processing Predictions:   0%|          | 5/7993 [00:05<2:14:20,  1.01s/it][E thread_pool.cpp:110] Exception in thread pool task: mutex lock failed: Invalid argument
# [E thread_pool.cpp:110] Exception in thread pool task: mutex lock failed: Invalid argument
# [E thread_pool.cpp:110] Exception in thread pool task: mutex lock failed: Invalid argument
# [E thread_pool.cpp:110] Exception in thread pool task: mutex lock failed: Invalid argument
# Processing Predictions:   0%|          | 5/7993 [00:05<2:34:58,  1.16s/it]
# saved
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 29
#      27         f.write(json_string)
#      28     print("saved")
# ---> 29     raise error
#      30 except Exception as error:
#      31     print(f"Failure for question {entry['question_id']} ({type(error).__name__}: {error})")
#
# Cell In[54], line 16
#      14 try:
#      15     context = build_context(entry)
# ---> 16     rag_context = rag_get_context(entry["question"], context, log=True)
#      17     #print(rag_context)
#      18     prediction = reader.predict(query=entry["question"], documents=[Document(rag_context)])
#
# Cell In[21], line 3, in rag_get_context(question, context, log)
#       1 def rag_get_context(question, context, log=False):
#       2     paragraphs = retrieve_wiki_headers_and_paragraphs(context, langchain=True)
# ----> 3     vectorstore = FAISS.from_texts(texts=paragraphs, embedding=HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2"))
#       4     retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": 1}, return_parents=False)
#       5     par = retriever.get_relevant_documents(question)
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/langchain/vectorstores/faiss.py:911, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#     884 @classmethod
#     885 def from_texts(
#     886     cls,
#    (...)
#     891     **kwargs: Any,
#     892 ) -> FAISS:
#     893     """Construct FAISS wrapper from raw documents.
#     894
#     895     This is a user friendly interface that:
#    (...)
#     909             faiss = FAISS.from_texts(texts, embeddings)
#     910     """
# --> 911     embeddings = embedding.embed_documents(texts)
#     912     return cls.__from(
#     913         texts,
#     914         embeddings,
#    (...)
#     918         **kwargs,
#     919     )
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/langchain/embeddings/huggingface.py:91, in HuggingFaceEmbeddings.embed_documents(self, texts)
#      89     sentence_transformers.SentenceTransformer.stop_multi_process_pool(pool)
#      90 else:
# ---> 91     embeddings = self.client.encode(texts, **self.encode_kwargs)
#      93 return embeddings.tolist()
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/sentence_transformers/SentenceTransformer.py:165, in SentenceTransformer.encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     162 features = batch_to_device(features, device)
#     164 with torch.no_grad():
# --> 165     out_features = self.forward(features)
#     167     if output_value == 'token_embeddings':
#     168         embeddings = []
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/nn/modules/container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/sentence_transformers/models/Transformer.py:66, in Transformer.forward(self, features)
#      63 if 'token_type_ids' in features:
#      64     trans_features['token_type_ids'] = features['token_type_ids']
# ---> 66 output_states = self.auto_model(**trans_features, return_dict=False)
#      67 output_tokens = output_states[0]
#      69 features.update({'token_embeddings': output_tokens, 'attention_mask': features['attention_mask']})
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:1022, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1013 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#    1015 embedding_output = self.embeddings(
#    1016     input_ids=input_ids,
#    1017     position_ids=position_ids,
#    (...)
#    1020     past_key_values_length=past_key_values_length,
#    1021 )
# -> 1022 encoder_outputs = self.encoder(
#    1023     embedding_output,
#    1024     attention_mask=extended_attention_mask,
#    1025     head_mask=head_mask,
#    1026     encoder_hidden_states=encoder_hidden_states,
#    1027     encoder_attention_mask=encoder_extended_attention_mask,
#    1028     past_key_values=past_key_values,
#    1029     use_cache=use_cache,
#    1030     output_attentions=output_attentions,
#    1031     output_hidden_states=output_hidden_states,
#    1032     return_dict=return_dict,
#    1033 )
#    1034 sequence_output = encoder_outputs[0]
#    1035 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:612, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     603     layer_outputs = torch.utils.checkpoint.checkpoint(
#     604         create_custom_forward(layer_module),
#     605         hidden_states,
#    (...)
#     609         encoder_attention_mask,
#     610     )
#     611 else:
# --> 612     layer_outputs = layer_module(
#     613         hidden_states,
#     614         attention_mask,
#     615         layer_head_mask,
#     616         encoder_hidden_states,
#     617         encoder_attention_mask,
#     618         past_key_value,
#     619         output_attentions,
#     620     )
#     622 hidden_states = layer_outputs[0]
#     623 if use_cache:
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:497, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     485 def forward(
#     486     self,
#     487     hidden_states: torch.Tensor,
#    (...)
#     494 ) -> Tuple[torch.Tensor]:
#     495     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     496     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 497     self_attention_outputs = self.attention(
#     498         hidden_states,
#     499         attention_mask,
#     500         head_mask,
#     501         output_attentions=output_attentions,
#     502         past_key_value=self_attn_past_key_value,
#     503     )
#     504     attention_output = self_attention_outputs[0]
#     506     # if decoder, the last output is tuple of self-attn cache
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:427, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     417 def forward(
#     418     self,
#     419     hidden_states: torch.Tensor,
#    (...)
#     425     output_attentions: Optional[bool] = False,
#     426 ) -> Tuple[torch.Tensor]:
# --> 427     self_outputs = self.self(
#     428         hidden_states,
#     429         attention_mask,
#     430         head_mask,
#     431         encoder_hidden_states,
#     432         encoder_attention_mask,
#     433         past_key_value,
#     434         output_attentions,
#     435     )
#     436     attention_output = self.output(self_outputs[0], hidden_states)
#     437     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:355, in BertSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     352     attention_scores = attention_scores + attention_mask
#     354 # Normalize the attention scores to probabilities.
# --> 355 attention_probs = nn.functional.softmax(attention_scores, dim=-1)
#     357 # This is actually dropping out entire tokens to attend to, which might
#     358 # seem a bit unusual, but is taken from the original Transformer paper.
#     359 attention_probs = self.dropout(attention_probs)
#
# File ~/triviaqa/.venv/lib/python3.9/site-packages/torch/nn/functional.py:1856, in softmax(input, dim, _stacklevel, dtype)
#    1854     dim = _get_softmax_dim("softmax", input.dim(), _stacklevel)
#    1855 if dtype is None:
# -> 1856     ret = input.softmax(dim)
#    1857 else:
#    1858     ret = input.softmax(dim, dtype=dtype)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Evaluation

# %%
import sys
sys.path.append("../")

# %%
from evaluation.triviaqa_evaluation import evaluate_triviaqa
from utils.dataset_utils import *
from utils.utils import read_json

# %%
dataset_file = 'triviaqa/sets/evaluation.json'
prediction_file = f'predictions/validation_predictions_{model_name}.json'

expected_version = 1.0
dataset_json = read_triviaqa_data(dataset_file)
if dataset_json['Version'] != expected_version:
    print('Evaluation expects v-{} , but got dataset with v-{}'.format(expected_version,dataset_json['Version']),
          file=sys.stderr)
key_to_ground_truth = get_key_to_ground_truth(dataset_json)
predictions = read_json(prediction_file)
eval_dict = evaluate_triviaqa(key_to_ground_truth, predictions)
# Out:
# em=0: The Sound of Music ['sunset boulevard', 'sunset bulevard', 'west sunset boulevard', 'sunset blvd']
# em=0: David Cameron ['henry campbell bannerman', 'sir henry campbell bannerman', 'campbell bannerman']
# em=0: her mother ['lauren becall', 'loren bacall', 'lauren becal', 'lauren bacall', 'betty j perske', 'betty perske', 'betty joan perske', 'bacall', 'betty joan perski']
# em=0: red ['greenishness', 'color green', '0 255 0', 'green color', 'green', 'rgb 0 255 0', 'avacado color', 'greenest', 'list of terms associated with color green', 'greenness', 'greenishly', 'colour green', 'pastel green', 'green colour']
# em=0: Def Leppard ['richard marx', 'richard noel marx']
# em=0: The Atlantics ['screaming abdabs', 'megadeaths', 'clive metcalfe', 'pink floyd band', 'pink flowd', 'meggadeaths', 'pi5', 'pink floyd', 'screaming ab dabs', 'grey floyd', 'architectural abdabs', 'pink flod', 'pinkfloyd', 'pik floyd', 'pink floyd sound', 'tea set', 'pink floid', 't set', 'pink floyd trivia', 'notable or frequent contributors to pink floyd']
# em=0: Highway 61 ['61', 'sixty one']
# em=0: Los Angeles, California, United States ['danubian carpathian area', 'roumania', 'austro hungarian empire romania', 'romania', 'rromania', 'iso 3166 1 ro', 'rou', 'country rom', 'ro country', 'rumunia', 'romainia', 'rumänien', 'etymology of romania', 'north danubian region', 'romînia', 'rumania', 'romanian state', 'carpathian danubian space', 'românia', 'republic of romania', 'roumanie']
# em=0: According to Jim (2001-2009) ['wild palms']
# em=0: the mutiny aboard HMS Bounty ['mutiny on bounty history', 'hms bounty mutineers', 'bounty vessel', 'mutiny on bounty', 'thomas ledward']
# em=0: Joseph Capote ['personhood theory', 'persons', 'person', 'perſon', 'perſons', 'person philosophical']
# em=0: An Agony in 8 Fits ['boojum disambiguation', 'boojum']
# em=0: The music video for 'Gangsta's Paradise ['my posse don t do homework', 'dangerous minds', 'dangerous minds film']
# em=0: Gerald Rudolff Ford Jr ['rudolf', 'rudolph', 'rodolphe', 'rudolph disambiguation', 'rodolph']
# em=0: poet and actor ['master builder occupation', 'graziani corazza', 'architecht', 'clifford lawrie', 'architechts', 'architects', 'registered architect', 'hok canada inc', 'architect', 'stanford downey architects inc']
# em=0: Dance Squad - Founded in 1967, same year as the Pacers franchise, the Indiana Pacemates were one of the original professional sports dance ['men s basketball', 'baksetball', 'baketball', 'boy s basketball', 'basketball club', 'high school basketball', 'rim basketball', 'basketball team', 'bball', 'unicycle basketball', 'basketball worldwide', 'shoot hoops', 'b ball', 'basketball', 'basketball net', 'women s hoops', 'basketball gear', 'basketballer', 'basket ball', 'basketball rim', '🏀', 'basketball parity worldwide', 'basketball player']
# em=0: Carnes's 1981 ['stars on 45 song', 'stars on 45 single', 'stars on 45 medley', 'medley intro venus sugar sugar no reply i ll be back drive my car do you want to know secret we can work it out i should have known better nowhere man you re going to lose that girl stars on 45']
# em=0: National Historic Site of Canada ['south vancouver british columbia', 'vansterdam', 'vancouvr', 'vancouver bc', 'vancover', 'vancouver british colombia', 'hong kouver', 'vancouver', 'vancouver bc canada', 'vancouverites', 'un locode cavan', 'vancouver christian school', 'vancouver b c canada', 'vancouver city centre british columbia', 'vanocuver', 'vancouver british columbia', 'corpus christi elementary', 'vancouverite', 'hongcouver', 'hong couver', 'hastings east vancouver', 'vancouver canada', 'vancover british columbia', 'corpus christi elementary school canada', 'city of vancouver', 'greater vancouver bridges', 'vancouver b c', 'vancouver british columbia canada']
# em=0: Early life ['kentuckian']
# em=0: the primordial sons of Uranus (Sky) and Gaia (Earth) and brothers of the Hekatonkheires and the Titans ['cyclopes disambiguation', 'cyclopes']
# em=0: Morton ['ferdinand morton', 'jellyroll morton', 'joseph ferdinand morton', 'f p lamothe', 'ferdinand lamothe', 'ferdinand joseph la menthe', 'ferdinand joseph morton', 'ferdinand joseph lamothe', 'jelly roll morton', 'louise monette', 'ferdinand 22jelly roll 22 morton']
# em=0: Ayacucho ['republic of perú', 'piruw suyu', 'iso 3166 1 pe', 'peruvian republic', 'perú', 'piruw ripuwlika', 'perù', 'lower peru', 'republic of peru', 'el peru', 'el perú', 'pérou', 'peruano', 'name of peru', 'peruvia', 'piruw', 'peru', 'república del perú', 'peruvian', 'etymology of peru', 'péru']
# em=0: 1970 ['27', 'twenty seven']
# em=0: British ['richard noble']
# em=0: Slow recovery  - Nicholas Balabkins concludes that "as long as German industrial capacity was kept idle the economic recovery of Europe was delayed ['marshall aid plan', 'european recovery act', 'economic cooperation act of 1948', 'marshall aid', 'marshal plan', 'marshall paln', 'european recovery programme', 'european recovery program', 'organization for european economic recovery', 'ministère de la reconstruction', 'operation rathole', 'marshall plan']
# em=0: Bill Cosby/Sidney Poitier ['cleotha staples', 'staple singers', 'staples singers']
# em=0: Boyz II Men ['too tight mc hammer album', 'family affair mc hammer album', 'stanley burrell', 'hammer rapper', 'stanley kirk burrell', 'stanley k burrell', 'wiredoo', 'mchammer', 'hammer crew', 'm c hammer', 'you shouldn t touch this', 'mc hammer']
# em=0: Diana Ross & the Supremes ['upside down diana ross song', 'up side down', 'upside down', 'upside down single']
# em=0: His artwork was used on the cover of the 1989 British Telecom telephone directory for Bradford ['hockney', 'david hockney']
# em=0: Grand Hotel, one which the American Film Institute in 2005 voted the 30th most memorable movie quote of all time,  "I want to be alone; I just want to be alone." The theme became a running gag beginning in her silent pictures ['grand hotel disambiguation', 'grand hôtel', 'grand hotel']
# em=0: cartoons published in the Daily Express ['cartoonish', 'cartoons', 'cartoon', 'cartoonistic', 'cartoonism', 'american cartoon']
# em=0: Richard Krajicek, Pat Cash, and Jan Kodeš ['virginia wade', 'sarah virginia wade']
# em=0: Willie Park Sr. ['hagen walter', 'walter hagen', 'walter charles hagen']
# em=0: Cinema International Corporation ['famous players film company', 'raleigh studios', 'famous players', 'celebrated players film corporation']
# em=0: Roald Amundsen ['sir edmund', 'edmond hillary', 'sir edmund hillary', 'edmund hillary', 'sir edmund percival hillary', 'edmund hilary', 'sir ed', 'ed hillary', 'sir edmund hilary', 'edmund percival hillary']
# em=0: News press ['dark side of camelot', 'seymour sy myron hersh', 'chain of command book', 'seymour hersch', 'seymour m hersh', 'seymour hersh', 'sy hersh', 'hersh seymour m', 'chain of command road from 9 11 to abu ghraib', 'seymour hirsch']
# em=0: Sir Terence Conran and mother to Sebastian Conran and Jasper Conran ['lydian stone', 'jaspis', 'egyptian jasper', 'youngite', 'bruneau jasper', 'jasper', 'jasper mineral', 'black jasper']
# em=0: Domino Sugar ['homemade pepsi', 'pepsiman', 'pep si', 'diet cherry pepsi', 'pepsi', 'pepsi gold', 'pepsi man', 'diet pepsi vanilla', 'peppsey', 'pepsi cola', 'pepsi vanilla', 'pepsi x', 'pepsi b', 'pepsi convoy', 'pepsi lime', 'pepsi cino', 'pepsi avantage', 'pepsi samba', 'pepsi limited edition summer mix', 'pepsi tarik', 'pepsi am', 'pepsi sí', 'pepsi advantage', 'brad s drink', 'cherry pepsi', 'pepsi perfect', 'pepsi cappuccino', 'pepsi summer mix', 'pepsicola', 'pepsi si', 'wildcherrypepsi', 'pepsi fire', 'pepsi edge', 'joy of cola', 'vanilla pepsi', 'cokesi', 'pepsey', 'brads drink', 'pepsi holiday spice', 'pepsi ice', 'mandarin orange slice', 'diet wild cherry pepsi']
# em=0: Monkey's Uncle ['carl wilson discography', 'carl dean wilson', 'carl wilson', 'wilson carl dean', 'wilson carl']
# em=0: Mark Wedloe ['ursidae', 'bear cub', 'cub bear', 'bear hibernation', 'ursoidea', 'bear', 'reproductive behavior of bears', 'honey pig', 'ursoid', 'bears', 'mating bears', 'ursine', '🐻', 'arctos', 'bear zoology', 'sexual behavior of bears']
# em=0: BBC sitcoms ['stretch cunningham', 'justice for all tv pilot', 'all in family us series', 'all in family', 'those were days tv pilot', 'millard fillmore high school']
# em=0: July 21 ['20 july', 'jul 20', 'historical anniversaries july 20', 'july 20th', 'july 20', '20th july']
# em=0: Geography ['legal system of brunei', 'state of brunei abode of peace', 'burnei', 'human rights in brunei', 'state of brunei darussalam', 'brunei darussalam', 'nation of brunei abode of peace', 'administrative divisions of brunei', 'state of brunei', 'asia brunei', 'brunei', 'brunei darrussalam', 'negara brunei darussalam', 'brunai', 'subdivisions of brunei', 'brunei darsussalam', 'iso 3166 1 bn', 'brunei sultanate', 'abode of peace', 'nation of brunei', 'بروني', 'برني دارالسلا', 'bruneian sultanate', 'health in brunei', 'etymology of brunei']
# em=0: photographer and filmmaker ['photographr', 'photographist', 'freelance photographer', 'photographer', 'freelance photography']
# em=0: Donald Sutherland and Shirley Douglas ['keifer sutherland', 'kiefer sutherland', 'kiefer william frederick dempsey george rufus sutherland', 'kiefer sutherlund', 'kiefer sutherland characters', 'promised land 1987', 'keefer sutherland', 'kiefer william fredrick dempsey george rufus sutherland', 'keifer southerland']
# em=0: three ['10', 'ten']
# em=0: Empire State of the South ['tyrus raymond cobb', 'cobb ty', 'ty cobb', 'tyrus cobb', 'georgia peach']
# em=0: 1967 ['johnny allen hendrix', 'jimmy hendrix', 'jim hendrix', 'jimi hendrix', 'jimy hendrix', 'hendrix', 'jimmy hendricks', 'early life of jimi hendrix', 'electric church', 'gypsy suns and rainbows', 'heaven research', 'villanova junction', 'james hendrix', 'al hendrix', 'james marshall hendrix', 'gypsy sun and rainbows', 'lithofayne pridgeon', 'janie hendrix', 'jimmi hendrix']
# em=0: Rick Hall and Billy Sherrill ['donald osmond', 'donald clark osmond', 'donny marie in las vegas', 'donnie osmond', 'donny osmond']
# em=0: General - Sean John Combs ['officially back', 'murda mase', 'murder mase', 'mase', 'ma e', 'now we even', 'murda ma e', 'karma mase album', 'mason betha', 'mason durell betha']
# em=0: beekeeper ['bee keepers', 'bee keeping', 'beekeeping', 'beekeeping helmet', 'bee farming', 'beekeeping suit', 'apairist', 'apiculture', 'history of beekeeping', 'beekiping', 'bee keeper', 'bee culture', 'beekeeping leading practices', 'apiarian']
# em=0: 1985 ['oprah gail winfrey', 'vernon winfrey', 'winfrey oprah gail', 'oprah winfre', 'patricia lee lloyd', 'oprahism', 'oprah s angels', 'opera winfrey', 'orpah winfrey', 'oprah winfry', 'oprah', 'oprah s last chapter', 'oprah winfrey', 'ophra', 'harpo radio inc', 'harpo winfrey', 'harpo inc', 'oprah winfery', 'oprah g winfrey']
# em=0: Sir Anthony ['richard nickson', 'resignation of richard nixon', 'richard milhouse nixon', 'nixon', 'dick nixon', 'nichard rixon', 'nixon richard m', 'nixon richard milhous', 'richard milhous nixon', 'i m not crook', 'harold nixon', 'nixonite', 'arthur nixon', 'tricky dick nixon', 'richard m nixon', 'harold samuel nixon', '37th president of united states', 'nixon richard', 'tricky dick', 'nixon s', 'nixson', 'nixonian', 'arthur burdg nixon', 'richard nixon']
# em=0: Love You to Bits and Pieces ['shine ep', 'shine album', 'shine disambiguation', 'shiné', 'shine', 'shine song']
# em=0: Thomas Harris ['roger william corman', 'doorway film', 'roger corman']
# em=0: The Nigger of the 'Narcissus ['aliens computer game', 'aliens disambiguation', 'alien disambiguation', 'alien song', 'aliens', 'alians disambiguation', 'aliens novel', 'alien', 'alien alien', 'aliens band', 'alien fictional creature']
# em=0: Nigel was three years old, the family moved to Cape Town, South Africa, where his father had bought a practice. Initially they lived in the Gardens and then moved to a newly built house near Camps Bay.Kathleen Riley ['george s', 'george disambiguation', 'gheevarghese', 'gheevargheese', 'geroge', 'ghevargheese', 'ghevarghese', 'vargheese', 'george', 'vargis']
# em=0: Albert Finney ['isotta ingrid rossellini', 'ingrid rossellini', 'ingrid berman', 'ingrid bergmann', 'ingrid bergman']
# em=0: Joan Crawford ['crawford', 'crawford village', 'crawford disambiguation']
# em=0: George Cukor
# * Best Actor: James Stewart ['james stewart actor', 'jimmy stuart', 'stewart james', 'jimmy stewart', 'james stewart']
# em=0: Steve McQueen ['fred astairey', 'fred astare', 'fred astair', 'frederick austerlitz astaire', 'fred austerlitz', 'phyllis potter', 'fred astaire', 'frederick austerlitz']
# em=0: The Best Little Whorehouse in Texas: original cast.  Audio CD.   MCA, 1997.  MCAD-11683; MCA-3049.
# *Best Little Whorehouse in Texas: New cast recording.  Audio CD.  Fynsworth Alley ['chicken ranch disambiguation', 'chicken ranch']
# em=0: aunt of British actress Jemma Redgrave ['daughters', 'daughter', 'daughterhood']
# em=0: Jonathan Rhys Meyers ['hingis', 'swiss miss', 'martina hingis', 'martina hingisova', 'martinahingis', 'martina hingisová']
# em=0: Colorado River ['climate of colorado', 'colarado', 'colorado state', 'state of colorado', 'colorado', 'colorada', 'us co', '38th state', 'colorado protected areas', 'demographics of colorado', 'protected areas of colorado', 'list of professional sports teams in colorado', 'kolorado', 'coloradans', 'insignia of state of colorado', 'list of military facilities in colorado', 'mother of rivers', 'fine arts in colorado', 'colorful colorado', 'coloradan', 'colorado united states', 'colo', 'list of professional sports teams of colorado', 'professional sports in colorado', 'religion in colorado', 'co state', 'colorado military facilities', 'list of former professional sports teams of colorado', 'colorado u s state', 'education in colorado', 'buffalo plains state', 'thirty eighth state', 'special districts of colorado', 'culture of colorado', 'centennial state', 'military facilities in colorado', 'list of colorado state insignia', 'columbine state', 'colorado state nickname', 'cuisines of colorado', 'emblems of state of colorado', 'professional sport teams of colorado', 'rocky mountain empire']
# em=0: 12 ['13', 'thirteen']
# em=0: Hollywood ['guess whose coming to dinner', 'guess who s coming to dinner 3f', 'guess who s coming to dinner']
# em=0: Sammy Ambrose ['gary lewis and playboys', 'dave gonzalez gary lewis playboys', 'gary lewis playboys']
# em=0: USSR ['ulf bergman', 'swea region', 'swedish origin', 'swedish climate', 'kingdom of sweden', 'sveden', 'suecia', 'swedish realm', 'zweden', 'iso 3166 1 se', 'mainland sweden', 'konungariket sverige', 'schweden', 'sweden', 'sverige', 'swedish sin', 'climate of sweden', 'etymology of sweden']
# em=0: Bristol, by David Kirke and Simon Keeling,  both members of the Oxford University Dangerous Sports Club.  The jumpers were arrested shortly after, but continued with jumps in the US ['newzealand', 'new zealand', 'aotearoa', 'kiwistan', 'new zeland', 'staten land', 'staten landt', 'neo zealand', 'new zeeland', 'mew zealand', 'new zealand s', 'new zealend', 'iso 3166 1 nz', 'nova zeelandia', 'aotearoa new zealand', 'nu tirani', 'subdivisions of new zealand', 'n zealand', 'new zealnd', 'new zealnad', 'new xealand', 'administrative divisions of new zealand', 'maoriland', 'nzl', 'niu tireni', 'new z', 'its got that new zeal', 'n z', 'name of new zealand', 'enzed', 'nz', 'new zaeland', 'new zelanad', 'sheepland', 'etymology of new zealand', 'kiwiland', 'māoria', 'staaten land', 'nouvelle zelande']
# em=0: lightweight baby buggy ['baby buggy']
# em=0: J ['harrison ford', 'ford harrison', 'harison ford', 'harrison ford actor']
# em=0: chase ['roger maris 61 home run season', 'roger eugene maras', 'roger eugene maris', 'roger maris', 'roger marris', 'roger maris museum', 'roger maras']
# em=0: world number 1 ['twelve', '12']
# em=0: AL ['boston braves', 'boston braves disambiguation']
# em=0: Hughes ['splendor in grass']
# em=0: popular British shows ['amos andy', 'brazilian brass mines', 'george 22kingfish 22 stevens', 'amos and andy', 'amos n andy show', 'amos n andy']
# em=0: Lennie Weinrib ['john astin']
# em=0: The Undertaker ['florence hendersen', 'florence agnes henderson', 'florence henderson', 'flo henderson']
# em=0: Stefan Edberg ['sampras', 'sampras pete', 'peter sampras', 'pete sampras', 'petros 22pete 22 sampras']
# em=0: Zheng ['to suijutsu', 'swam', 'swimming disambiguation', 'swimming']
# em=0: Grand Slam Cup ['french disambiguation', 'french', 'frenchness', 'francaise', 'francais', 'frrench', 'français']
# em=0: ninth ['three', '3']
# em=0: General - A person who creates electronic spam is called a spammer ['junkmail', 'junkmailing', 'junk mail', 'junk mail disambiguation']
# em=0: global ['u s of america', 'u–s–', 'estatos unitos', 'amarica', 'america united states of', 'v s amerika', 'states of america', 'amurika', 'unitesd states', 'estados unidos de america', 'america', 'united states of america oldpage', 'america us', 'nited states', 'etats unis d amerique', 'united stated', 'verenigde state van amerika', 'america united states', 'merica', 'amurka', 'amurica', 'v s america', 'us', 'americophile', 'états unis d amérique', 'united states america', 'الولايات المتحدة الأمريكية', 'eeuu', 'amercia', 'united states of america u s', 'unitd states', 'us america', 'estados unidos', 'etymology of united states', 'america magazine', 'u s american', 'united states of america usa', 'united states of amerca', 'united states u s', 'us and', 'etats unis', 'untied states of america', 'united states introduction', 'america usa', 'u s of', 'iso 3166 1 us', 'federal united states', 'usofa', 'americia', 'untied states', 'america class', 'american united states', 'nagkaisang mga estado', 'estaos unios', 'vs america', 'united states', 'united states country', 'los estados unidos de america', 'los estados unidos de américa', 'america country', 'yankee land', 'usoa', 'u s', 'united states us', 'united states of america redirect', 'vereinigte staaten', 'estados unidos de américa', 'ee uu', 'unites states', 'stati uniti d america', 'los estados unidos', 'estaos uníos', 'amerka', 'us country', 'usa', 'unitedstates', 'unite states of america', 'états unis', 'united state of america', 'united staets of america', 'us of', 'unites states of america', 'united sates', 'u–s', 'name of united states', 'u s america', 'us of america', 'u –s –', 'united states of american', 'united states of america introduction', 'verenigde state', 'americaland', 'vs amerika', 'these united states of america', 'unite states', 'unietd states', 'united states of america', 'united–states', 'u –s']
# em=0: No Exit and The Curse of Blondie ['teaching of rapture', 'pre tribulation rapture', 'rapture protestant belief', 'midtribulation rapture', 'rapture', 'pretribulation rapture', 'pre tribulational', 'mid tribulation rapture', 'midtribulationism', 'pretribulationistism', 'pre trib', 'pre tribulation']
# em=0: Cynthia Ann ['pressly', 'presley', 'pressley']
# em=0: Royal Borough of Kensington and Chelsea, London ['names of egypt', 'jumhuriyat misr al arabiyah', 'eytp', 'iso 3166 1 eg', 'egypt', 'r egypt', 'eygpt', 'kimet', 'name of egypt', 'جمهورية مصرالعربية', 'arab republic of egypt', 'egypt name', 'gift of nile', 'kemmet', 'miṣr', 'egipto', 'جمهوريّة مصرالعربيّة', 'egy', 'egypt info', 'egyptian republic', 'egypte', 'eypt', 'ejipt', 'national identity of egyptians', 'égypte', 'etymology of egypt', 'egipt', 'مصر', 'second egyptian republic', 'republic of eygpt']
# em=0: Burmese ['myanmar formerly burma', 'republic of union of myanmar', 'myanmar burma', 'union of myanmar', 'birmania', 'union of burma', 'birman empire', 'birma', 'burmese republic', 'pyidaunzu thanmăda myăma nainngandaw', 'etymology of burma', 'ပြည်ထောင်စု သမ္မတ မြန်မာနိုင်ငံတော်', 'economic sanctions against myanmar', 'mayanmar', 'sanctions against burma', 'socialist republic of union of burma', 'birmanie', 'economic sanctions against burma', 'iso 3166 1 mm', 'pyi daung zu myan ma naing ngan daw', 'borders of burma', 'eastern burma', 'burma', 'myanmer', 'myanma', 'မြန်မာပြည်', 'myanmar', 'mianmar', 'myammar', 'burma myanmar', 'ပြည်ထောင်စု သမ္မတ မြန်မာနိုင်ငံတော']
# em=0: D. W. Griffith, Charlie Chaplin, Mary Pickford, and Douglas Fairbanks ['chaplin disambiguation', 'chaplin', 'chaplin musical']
# em=0: the cage of mad women ['discothèques', 'discoteck', 'history of discotheques', 'clubgoer', 'clubbers', 'dance club', 'disco bar', 'discotheke', 'history of nightclubs', 'theque', 'club night', 'list of nightclubs', 'discotheques', 'night clubs', 'nightclubs', 'night club', 'nightclub', 'discotek', 'discothek', 'diskotek', 'club scene', 'discotheque', 'dance clubs', 'clubber', 'discoteque', 'discothèque', 'discotech', 'disco pub', 'nightclub culture']
# em=0: 2% ['8', 'eight']
# em=0: Vichy France ['durocortorum', 'rheims france', 'rheims', 'saint remi basilica', 'reims', 'reims france', 'saint remi cathedral']
# em=0: Jimmy MacDonald ['celebrity productions', 'iwerks ub', 'ub iwerks', 'ubbe ert iwwerks', 'ub iwerks studio']
# em=0: Julie Edwards ['julie elizabeth wells', 'julie elizabeth andrews dbe', 'julie elizabeth andrews', 'julia elizabeth wells', 'julie andrews', 'julie wells', 'dame julie andrews', 'julie andrews edwards']
# em=0: Warner Bros ['east atlantic', 'atlantic ocean', 'north atlantic ocean', 'ethiopian ocean', 'oceanvs occidentalis', 'atlantic basic', 'south atlantic', 'altantic ocean', 'south atlantic ocean', 'atlantic basin', 'north atlantic fisheries', 'northern atlantic', 'north east atlantic', 'antlantic ocean', 'sea of atlas', 'occidental ocean', 'atlantic', 'across pond', 'atlantic coast', 'atlantic oceans', 'north atlantic', 'ethiopic ocean', 'pond', 'central atlantic', 'atlantis thalassa']
# em=0: Pittsborough ['steel city', 'climate of pittsburgh pennsylvania', 'pittsbrugh', 'un locode uspit', 'pittsburgh', 'pittsburgh frick 6–8 middle school', 'pittsburgh pennsylvania usa', 'pittsburgh style', 'city of pittsburgh', 'pittsburgh pennsylvania u s', 'st justin s high school', 'pittsburgh pa', 'glenwood pennsylvania', 'da burgh', 'pittsburgh style of literature', 'pitsburgh', 'east end pittsburgh', 'pittsburgh pennsylvania us', 'pittsburgh usa', 'smoky city', 'city of bridges', 'fort du quesne', 'pittsburg pennsylvania', 'pittsburgh frick 6 8 middle school', 'pittsburgh pennsylvania', 'pittsburgh united states of america', 'education in pittsburgh', 'pittsburg pa', 'pittsburgh pennsyvania', 'burgh', 'frick international studies academy middle school', 'pittsburgh allegheny county pennsylvania', 'pittsburgh pgh']
# em=0: Florraine Darlin ['bobby vinton']
# em=0: The plates are made of aluminum with reflective base and embossed characters ['is', 'i s', 'is disambiguation']
# em=0: Wembley Stadium ['birthplace of america', 'philadelpia pa', 'philadelphia pennsylvania u s', 'un locode usphl', 'philadephia pennsylvania', 'government of philadelphia', 'city and county of philadelphia pennsylvania', 'philidelphia', 'philadelphia commuter rail', 'philedelphia', 'philladelphia', 'philadelphia pa', 'philadelpia pennsylvania', 'philadelphia city', 'philadelphia', 'philadelphia pennsylvania us', 'philadelphia pennsylvania', 'political families of philadelphia', 'philadelphia regional rail', 'list of nicknames for philadelphia', 'philadelphi', 'phila', 'philadelphia u s', 'philadelphia suburban rail', 'cradle of liberty', 'philidalphia', 'philadelphia usa', 'city that loves you back', 'philadelphia city pennsylvania', 'city of brotherly love', 'wiccacoa', 'philadelphia united states', 'philadelphia philadelphia county pennsylvania', 'philadelphia city controller', 'quaker city', 'city of philadelphia', 'philadelphia pennsylvania usa']
# em=0: Heinrich Himmler ['himler s evil genius', 'heidrich reinhart', 'heidrich rhinehard', 'reinhart heydrich', 'reinhard heydrich', 'himmler s evil genius', 'heidrich rinehart', 'heidrich reinhard', 'reinhard hydrich', 'reinhard heydrick', 'reinhardt heydrich', 'rinehard heidrich', 'reinhart heidrich', 'rhinehardt heydrich', 'rhinehart heidrich', 'heydrichreinhard', 'reinhardheydrich', 'rinehard heydrich', 'reinhard heidrich', 'reihnard heidrich', 'heydrich reinhardt', 'heydrich reinhard', 'heydrich reinhart', 'reinhard hidrick', 'rhinehardt heidrich', 'rhinehard heidrich', 'butcher of prague', 'rinehart heidrich', 'heidrich rhinehart', 'heydrich', 'reinhard hidrich', 'reinhard hydrick', 'rhinehart heydrich', 'heidrich rinehardt', 'rheinhard heydrich', 'rinehart heydrich', 'rhinehard heydrich', 'young evil god of death', 'reinhard tristan eugen heydrich', 'rinehardt heydrich', 'heydrichreinhardt', 'reinhardtheydrich', 'heidrich rinehard', 'rinehardt heidrich', 'heidrich reinhardt', 'heidrich rhinehardt']
# em=0: Ferdinand Marcos ['marcos disambiguation', 'markos', 'marcos']
# em=0: Spitak earthquake ['地震', 'earth quakes', 'earthquakes', 'tectonic earthquake', 'causes of earthquakes', 'seismic activity', 'earth quake', 'kinds of earthquakes', 'seismic movement', 'site effects earthquake', 'low magnitude earthquake', 'seismically active', 'seismic event', 'earthquake', 'earth tremor', 'earthshake', 'seismicity', 'main shock', 'quake weapons', 'seism', 'speedjump']
# em=0: December 7, 1941 ['dec', '㋋', 'decembre', 'december', 'xber']
# em=0: Cora Henrietta Crippen ['his wife']
# em=0: ten ['twenty one', '21']
# em=0: at 12:30 pm Central Standard Time ['shot unit', 'shot disambiguation', 'shot drink', 'shot', 'shot alcohol', 'shot beverage']
# em=0: Laura Ling and Euna Lee ['richard nickson', 'resignation of richard nixon', 'richard milhouse nixon', 'nixon', 'dick nixon', 'nichard rixon', 'nixon richard m', 'nixon richard milhous', 'richard milhous nixon', 'i m not crook', 'harold nixon', 'nixonite', 'arthur nixon', 'tricky dick nixon', 'richard m nixon', 'harold samuel nixon', '37th president of united states', 'nixon richard', 'tricky dick', 'nixon s', 'nixson', 'nixonian', 'arthur burdg nixon', 'richard nixon']
# em=0: the Right Honourable the Lord Tweedsmuir, Governor General and Commander-in-Chief of the Militia and Naval and Air Forces of Canada ['buchan john', 'buchan john sir', 'sir john buchan', 'john scantlebury blenkiron', 'lord tweedsmuir', 'john buchan 1st baron tweedsmuir', 'john buchan', 'baron tweedsmuir of elsfield', 'john buchan baron tweedsmuir', 'john sir buchan', 'buchanesque', 'john s blenkiron', 'john blenkiron']
# em=0: 1965 ['1914', 'one thousand nine hundred and fourteen']
# em=0: Heard Island and McDonald Islands ['maldivies', 'maldive', 'maldives history', 'maldives', 'islamic republic of maldives', 'iru fushi', 'largest cities in maldives', 'iso 3166 1 mv', 'republic of maldives', 'ދިވެހިރާއްޖޭގެ ޖުމުހޫރިއްޔާ', 'indian maldives', 'employment labour in maldives', 'maldivas', 'government of maldives', 'religion in maldives', 'maldives island', 'maledives', 'rep of maldives', 'irufushi', 'maldivian republic', 'maldive islands', 'etymology of maldives', 'republic of maldive islands', 'ދިވެހިރާއްޖެ', 'environmental issues in maldives', 'sultanate of maldives', 'dehevi jumhuriyya']
# em=0: King of France (and Navarre ['louis bourbon', 'louis xvi', 'louis seize', 'louis capet', 'louis 16', 'king louis xvi of france', 'louis auguste louis xvi', 'louis vi of france', 'king louis 16', 'louis xvi king of french', 'louis sixteenth', 'louis auguste de france', 'louis ⅹⅴⅰ', 'king louis xvi', 'citoyen louis capet', 'louis auguste duke of berry', 'louis 16 of france', 'louis xvi of france', 'sophie beatrix']
# em=0: Second Crusade, the Zengid dynasty controlled a unified Syria and engaged in a conflict with the Fatimid rulers of Egypt. The Egyptian and Syrian forces were ultimately unified under Saladin, who employed them to reduce the Christian states and recapture Jerusalem in 1187. Spurred by religious zeal, King Henry II of England and King Philip II of France (known as Philip Augustus) ended their conflict with each other to lead a new crusade ['kings crusade', '3rd crusade', 'third crusade', 'crusade of 1189']
# em=0: Henry VIII ['queen catherine parr', 'kateryn parre', 'katheryn parre', 'queen katherine parr', 'lady latimer', 'katharine parr', 'katharine parre', 'catherine borough', 'catherine parr', 'katherine borough', 'catherine parre', 'katherine parr', 'anthony martienssen', 'lady lattimer', 'kateryn parr', 'katheryn parr', 'katherine parre']
# em=0: Swiss canton of Aargau ['der schweiz', 'switzeland', 'confederation helvetia', 'confederatio helvetica', 'swissland', 'switzerland information', 'confederation suisse', 'switserland', 'confédération suisse', 'swizterland', 'confederation of helvatia', 'swizerland', 'svizzera', 'confederation helvetica', 'land of switzers', 'suiza', 'confederaziun svizra', 'schweiz', 'etymology of switzerland', 'die schweiz', 'suisse', 'confederazione svizzera', 'swiss', 'svizra', 'switzerland', 'schweitz', 'swiss confederation', 'switz', 'svissland', 'schwitzerland', 'environmental integrity group', 'land of swiss', 'schweizerische eidgenossenschaft', 'swissenergy', 'confœderatio helvetica', 'confoederatio helvetica', 'switzer land', 'švýcarsko', 'swiss confederated states', 'iso 3166 1 ch']
# em=0: General - The Green Party,  also known as the Green Party UK ['green party of united kingdom', 'green party 1985 90', 'uk green party', 'british green party', 'green parties uk', 'green party of great britain', 'green party 1985–1990', 'people movement', 'green party uk', 'people party uk 1973 75', 'ecology party', 'green parties united kingdom', 'green party united kingdom']
# em=0: Plurality/Majoritarian systems ['fptp', 'simple majority', 'multiple member first past post voting', 'first pass post', 'first past post election system', 'first past post electoral system', 'first past post method', 'first past post system', 'first past post voting', 'first past post fptp', 'first past post']
# em=0: patriota, meaning "countryman", ultimately , .  The abstract noun patriotism ['chauvinist', 'chauvinistic', 'chauvanistic', 'chauvenism', 'male chauvinist', 'chauvanism', 'male chauvinism', 'chauvinist pig', 'chauvanist', 'male chauvinists', 'male chauvinist pigs', 'female chauvinism', 'male chauvinist pig', 'chauvinism']
# em=0: Watt  - Boulton ['james watt of scottland', 'watt james', 'james watt of scotland', 'james watt inventor', 'james watt']
# em=0: Édith Giovanna Gassion ['little sparrow']
# em=0: sodium selenite ['sand grain', 'floor sugar', 'desert sand', 'sandiest', 'sand', 'coversand', 'psammophilous', 'grains of sand', 'psammophile']
# em=0: subterranean Ascomycete fungus ['fungii', 'mycota', 'multicellular fungi', 'sexuality of fungi', 'fungis', 'eumycetes', 'fungal proteins', 'fungi', 'mycete', 'funghi', 'fungal growth', 'mycetes', 'eumycota', 'fungi kingdom', 'fungal development', 'antigens fungal', 'fungal', 'antibodies fungal', 'fungus kingdom', 'kingdom fungi', 'fungus', 'fugus', 'mycetae', 'fungus plants']
# em=0: Introduction - Liquid ['evaporates', 'vaporized', 'evaporate', 'evaporation', 'vaporizing', 'evaporating', 'evaporated', 'evapouration', 'evapourate', 'vaporizes', 'vapourization', 'verdunstung', 'évaporation', 'vaporise', 'vapourise']
# em=0: scientific research  - Discoveries in fundamental science ['arithmetic operations', 'arithmetics', 'arithmetic operators', 'history of arithmetic', 'arithmetic', 'additive operator', 'arithmatic', '−×÷', 'x', 'arithmetic operation', 'multiplicative operator', 'rithmetic', 'arithmetician', 'arithmetic operator', 'arithmetik', 'aritmetika', 'arithmetical operations']
# em=0: friction is a manifestation of the electromagnetic force ['coefficient of kinetic friction', 'frictional force', 'angle of friction', 'force of friction', 'coulomb s law of friction', 'coulomb friction', 'starting friction', 'internal friction', 'frictionless', 'friction coefficients', 'kinetic friction', 'dry friction', 'friction physics', 'static friction', 'friction coefficient', 'dynamic friction', 'sliding friction', 'coefficient of static friction', 'contact friction', 'coefficient of friction', 'frictional coefficient', 'limiting friction', 'friction', 'coefficient of sliding friction', 'friction angle']
# em=0: Testudines ['alligators', 'alligator', 'aligator']
# em=0: brown seaweeds too expensive when compared to the costs of harvesting and transporting wild seaweeds. The only exception is for Laminaria japonica ['kelp', 'laminariales', 'kelps']
# em=0: General - Myoglobin was the first protein to have its three-dimensional structure revealed by X-ray crystallography ['muscle tissue']
# em=0: morphospecies ['ant', 'ant trails', '🐜', 'drone ant', 'formicidae', 'ants communication', 'history of ants', 'giant ant', 'ergate', 'ants', 'ant trail', 'worker ant']
# em=0: General - Ethology ['natural behavior', 'animal behavior', 'ethological', 'behavior animal', 'history of ethology', 'animal learning', 'bestial instinct', 'behavioural biology', 'behaviour biology', 'animal behaviorist', 'social ethology', 'behavior biology', 'ethography', 'animal behaviour', 'ethologist', 'ethologists', 'behavioral biology', 'etology', 'ethology']
# em=0: females with smaller litters ['squirrels', 'squirrl', 'eichhornchen', 'scuiridae', 'squirell', 'skiouros', 'sciuridae', 'squirrell', 'scuridae', 'squirrel', 'rats with bushy tails', 'bushy tailed tree rat', 'bigtail rat', 'eichhoernchen', 'sciurid', 'squirel', 'squirl', 'eichhörnchen']
# em=0: birds ['beaverdams', 'beaver pelt', 'beaverdam habitat', 'beaver', 'beavers', 'beaver lodge', 'beaver houses', 'castor zoology', 'salt water beavers', 'beaver house', 'castor genus', 'beever']
# em=0: glucagon ['insulin zinc susp prompt beef', 'insulin zinc susp purified beef', 'insulin gene', 'insulin pork', 'insulin zinc susp beef', 'insulin human', 'insulin zinc susp extended purified beef', 'human mixtard', 'insulin recombinant human', 'insulin purified beef', 'insulin antagonists', 'iletin i beef pork', 'insulin zinc susp purified pork', 'insulin purified pork', 'actrapid', 'insulin zinc susp prompt purified pork', 'insullin', 'iletin ii', 'oral insulin', 'insulin zinc susp recombinant human', 'insulin aspart recombinant', 'c257h383n65o77s6', 'insulin recombinant purified human', 'insulin glargine recombinant', 'mixtard', 'actraphane', 'insulin zinc susp extended beef', 'insuline', 'insulin zinc susp extended recombinant human', 'ins gene', 'insulin', 'insulin zinc susp semisynthetic purified human', 'c65r', 'b10h', 'insulin release', 'aktrapid', 'insulin porcine']
# em=0: fertilizable egg ['theca lutein cell', 'corpora lutea', 'corpora luteum', 'corpus luteum', 'corpus lutea', 'lutein cyst', 'corpus luetum', 'luteal cells', 'corpora albicantia', 'corpus luteum graviditatis', 'corpus albicantia', 'yellow bodies', 'corpus luteum hormones', 'corpus leteum', 'granulosa lutein cell', 'luteal', 'corpus luteum cell', 'yellow body', 'luteal cell']
# em=0: Hormone therapy ['receptors lh', 'leutenizing hormone', 'lutropin alfa', 'lutropin', 'lh kit', 'ovulation predictor kit', 'lutenising hormone', 'atcvet code qg03ga07', 'pee stick', 'ovulation prediction kit', 'luteinizing', 'interstitial cell stimulating hormone', 'lutenizing hormone', 'leutinizing hormone', 'atc code g03ga07', 'lh surge', 'lh test', 'luteinizing hormone', 'luteinising hormone', 'luveris']
# em=0: nitrogen ['dioxygen molecule', 'molecular oxygen', 'atcvet code qv03an01', 'element 8', 'e948', 'sauerstoff', 'oxyjunn', '0xygen', 'diatomic oxide', 'pure oxygen', 'o element', 'atomic number 8', 'oxigen', 'history of oxygen', 'oxygen', 'oxygyn', 'oxygen atom', 'atc code v03an01', 'vital air', 'oxygen partial pressure', 'oxygen rings', 'oxygen ion', 'o₂', 'active oxygen', 'diatomic oxygen', 'oxygen gas']
# em=0: gamma rays, neutrons ['household radon', 'thoron', 'radium emanation', 'radon element', 'radon rn', 'element 86', 'actinon', 'niton element', 'radon poisoning', 'radon', 'radon gas', 'emanation chemistry']
# em=0: Portland cement ['calcium sulfate dihydrate', 'caso4 2h2o', 'gipsum', 'caso4·2h2o', 'gypsum']
# em=0: Armstrong ['neil alden armstrong', 'neil armstrong', 'one small step for man', 'niel armstrong', 'first man on moon', 'armstrong neil alden', 'that s one small step for man', 'that s one small step for man one giant leap for mankind', 'neil armstorng', 'neal armstrong', 'astronaut armstrong']
# em=0: a barred spiral galaxy ['speed of milky way through space', 'local galaxy', 'milky way galaxy', 'milky way astronomy', 'milky way', '🌌', 'our galaxy', 'milky way band of light', 'this galaxy', 'age of milky way', 'milkyway', 'via lactea', 'lactea', 'spiral arms of milky way', 'galaxia kuklos']
# em=0: General - Winfrey was born into poverty in rural Mississippi to a teenage single mother and later raised in an inner-city Milwaukee neighborhood. She has stated that she was molested during her childhood and early teens and became pregnant at 14; her son died in infancy. ['color purple novel', 'colour purple', 'color purple']
# em=0: hydrogen and helium ['solid helium', 'helium ii', 'helium shortage', 'atcvet code qv03an03', 'two fluid model for helium', 'helium', 'helium gas', 'superfluid helium', 'element 2', 'atomic number 2', 'he element', 'balloon grade helium', 'inhaling helium', 'e939', 'atc code v03an03']
# em=0: alfajores ['fifty seven', '57']
# em=0: A.C. Milan ['ian wright', 'mr wright']
# em=0: one or two ['three', '3']
# em=0: red ['color white', 'white political adjective', 'whitishness', 'rgb 255 255 255', '255 255 255', 'ffffff', 'whitishly', 'white colour', 'man on white horse', 'white', 'whiter', 'white finn', 'whitest']
# em=0: German Democratic Republic ['early years of john f kennedy', 'camelot era', 'j f k administration', 'j f k', 'john fitzgerald kennady', 'kennedyesque', 'john f kenedy', 'john f kennedy', 'jfk administration', 'john f kennedie', 'president kennedy', 'john f 22jack 22 kennedy', 'u s president j f kennedy', 'kennedyism', 'jack kennedy', 'jfk president', 'jf kennedy', 'eponyms of john f kennedy', 'jfk', 'president john f kennedy', 'john fitzgerald kennedy', 'j f kennedy', 'kennedy john f', 'john fitzgerald 22jack 22 kennedy', 'jhon f kennedy', 'kennedy era', 'john kennedy', 'my god i m hit', 'john f k', 'kennedy administration', '35th president of united states', 'president john kennedy', 'john f kennedy and civil rights', 'senator john f kennedy']
# em=0: Iditarod Trail Sled Dog Race ['denali south buttress', 'большая гора', 'mount mckinley south buttress', 'mount mckinley alaska', 'denali', 'mt denali', 'mount mckinely', 'mount mckinley', 'denali north peak', 'highest mountain in north america', 'mount mckinley east buttress', 'mt mckinley denali', 'mount mckinley north peak', 'churchill peaks', 'mount denali', 'mt mckinley', 'denali east buttress']
# em=0: acidic ['3 hydroxypentanedioic acid 3 carboxylic acid', 'citrus acid', 'hydrogen citrate', 'sour salt', 'hoocch2 oh c cooh ch2cooh', 'citric acid', '2 hydroxy 1 2 3 propanetricarboxylic acid', 'e 330', 'e330', 'acid of lemon', 'atc code a09ab04', 'atcvet code qa09ab04']
# em=0: 253 ['twenty eight', '28']
# em=0: Inspectorate-General ['international criminal police commission', 'international criminal police organization – interpol', 'international criminal police organization interpol', 'icpo interpol', 'international criminal police organisation', 'interpol organization', 'interpol', 'international criminal police organization', 'international police commission', 'international police conference', 'president of interpol']
# em=0: 1768 and 1771 ['1768', 'one thousand seven hundred and sixty eight']
# em=0: Hammersmith & City and Circle ['jubilee line', 'fleet line']
# em=0: Oliver Parker ['o flahertie', 'theocritus villanelle', 'flahertie', 'oscar wilde biblio', 'oscar fingal o flahertie wills wilde', 'o wilde', 'oscar fingal o flaherty wills wilde', 'oscar wilde', 'oscar o flaherty wilde', 'c 3 3 3', 'sebastian melmoth', 'oscar o flahertie wills wilde', 'oscar wild', 'cyril wilde']
# em=0: The letters b, d, f, h, j, k, l, m, n, p, r, s, t, v, w, y, z represent, respectively, the phonemes ['true song', 'true disambiguation', 'truer', 'true', 'true album']
# em=0: armaments ['dynamite', 'dynamited', 'dinamite']
# em=0: Great Lakes Megalopolis ['us ny', 'n y', 'neo york', '11th state', 'new york state s', 'nýja jórvík', 'new yourk', 'new york us', 'new york', 'estado nueva york', 'nova york', 'ny state', 'state new york', 'new yourk state', 'u s state of new york', 'eleventh state', 'state of n y', 'new york u s', 'new york s', 'n y u s state', 'newyork', 'new york usa state', 'new yrok', 'state of new yourk', 'state of new york', 'nyja jorvik', 'ny', 'estado de nueva york', 'religion in new york', 'nueva york estado', 'new york u s state', 'new york state', 'state of ny', 'n y state', 'us state of new york', 'nys', 'new york population', 'ny u s state']
# em=0: Braille ['q alphabet', '⒬', 'ｑ', '🅀', 'q letter', 'ⓠ', '🅠', 'q', '🄠', '🆀']
# em=0: Spiceworld ['wannabes disambiguation', 'wannabes', 'wannabe disambiguation', 'wanna be', 'wannabe', 'wannabee']
# em=0: triple flat () can sometimes be found. It lowers a note three semitones ['c and f']
# em=0: Belgium ['der schweiz', 'switzeland', 'confederation helvetia', 'confederatio helvetica', 'swissland', 'switzerland information', 'confederation suisse', 'switserland', 'confédération suisse', 'swizterland', 'confederation of helvatia', 'swizerland', 'svizzera', 'confederation helvetica', 'land of switzers', 'suiza', 'confederaziun svizra', 'schweiz', 'etymology of switzerland', 'die schweiz', 'suisse', 'confederazione svizzera', 'swiss', 'svizra', 'switzerland', 'schweitz', 'swiss confederation', 'switz', 'svissland', 'schwitzerland', 'environmental integrity group', 'land of swiss', 'schweizerische eidgenossenschaft', 'swissenergy', 'confœderatio helvetica', 'confoederatio helvetica', 'switzer land', 'švýcarsko', 'swiss confederated states', 'iso 3166 1 ch']
# em=0: Harry Potter and the Philosopher's Stone won almost all the UK awards judged by children, but none of the children's book awards judged by adults,  and Sandra Beckett suggested the reason was intellectual snobbery towards books that were popular among children. In 1999, the winner of the Whitbread Book of the Year award children's division was entered for the first time on the shortlist for the main award, and one judge threatened to resign if Harry Potter and the Prisoner of Azkaban ['hp 3', 'third harry potter book', 'harry potter and prisoner of azkaban book', 'prisoner of azkaban', 'harry potter and prisoner of azkaban', 'hp3', 'harry potter iii', '3rd harry potter book', 'harry potter prisoner of azkaban', 'hppoa', 'harry potter and prisoner of azkhaban', 'harry potter 3', 'hary potter and prisoner of azkaban']
# em=0: pangram ['type wrote', 'type bar', 'typewriter', 'electronic word processor', 'typewriter eraser', 'manual typewriter', 'personal word processor', 'type machine', 'typewriting', 'typewrites', 'typebars', 'type writer', 'type writers', 'typebar', 'type written', 'typewrote', 'type writing', 'electric typewriter', 'type write', 'typewriter ribbons', 'typing machine', 'first typewriter', 'typebasket', 'type writes', 'typewriterly', 'typewriter carriage', 'electronic typewriter', 'typewrite', 'typewriters', 'typewriter keyboard', 'electromechanical typewriter', 'type writerly', 'typewritten']
# em=0: Huey, Dewey and Louie Duck - Huey, Dewey, and Louis Duck ['huey duey and louis', 'huey dewey and louie', 'ripp rapp og thorfinnur', 'huey dewey', 'huebert duck', 'donald duck s nephews', 'louie duck', 'huey dewey and louie filmography', 'huey duck', 'louis duck', 'huey dewey and louie duck', 'huey louie and dewey', 'dewey duck', 'ripp rapp og þorfinnur', 'phooey duck', 'deuteronomy duck', 'huey dewie and louie', 'huey duey and louie', 'ripp rapp og rupp', 'huey dewey louie']
# em=0: West Germanic ['o f', 'of disambiguation', 'of']
# em=0: Blade Runner: Do Androids Dream of Electric Sheep? in some later printings) is a science fiction novel by American writer Philip K. Dick. First published in 1968, the novel is set in a post-apocalyptic San Francisco, where Earth's life has been greatly damaged by nuclear global war. Most animal species are endangered or extinct from extreme radiation poisoning, so that owning an animal is now a sign of status and empathy, an attitude encouraged towards animals. The book served as the primary basis for the 1982 film Blade Runner ['blade runner 2 2014 film', 'untitled blade runner sequel', 'blade runner', 'voight kampff machine', 'voigt kampff machine', 'c beams', 'blade runner 1982 film', 'voight kampff', 'voigt kampff', 'voight kampf', 'spinner blade runner', 'voit kampf test', 'voigt kampf', 'leon kowalski', 'methuselah syndrome', 'blade runner 2', 'blade runner 1982', 'voight kampff test', 'voit kampf', 'blade runner 2 film project', 'dangerous days', 'v k', 'voigt kampff test', 'blade runner 2 film', 'blade runner 2014 film', 'blade runner film']
# em=0: 1973 American-British animated ['fox habitat', 'vulpini', 'focks', 'foxs', 'vulpine', 'fox zoology', 'sexual characteristics of foxes', 'foxes', 'fox penis', 'foxp', 'vixen', 'todde', 'fox', 'river fox']
# em=0: Joanne Froggatt ['neil anthony morrissey', 'neil morrisy', 'neil morisey', 'neil morissey', 'neil morrissey', 'neil morrisey']
# em=0: Henry: Portrait of a Serial Killer ['jack rippers victims', 'ripperologist', 'ripperology', 'jack ripper non fiction', 'ada wilson', 'leather apron', 'annie millwood', 'pinchin street murder', 'ripperologists', 'fairy fay', 'jack ripper', 'leatherapron', 'annie farmer', 'whitechapel murderer']
# em=0: 87 ['nelson disambiguation', 'nélson', 'nelson film', 'nelson']
# em=0: How to Be Good ['hornby nick', 'nick hornby']
# em=0: Good Morning to All ['happy birthday film', 'happy birthday disambiguation', 'happy birthday', 'happy birthday song', 'hapy birthday', 'happy birthday album']
# em=0: An authoritative list of the most common pub names in Great Britain is hard to establish, owing to ambiguity in what classifies as a pub as opposed to a licensed restaurant or nightclub ['red lion', 'red lion disambiguation']
# em=0: Sheila ['pear wine', 'perry drink', 'pear scrumpy', 'perry', 'pear cider']
# em=0: redivider ['race driver', 'autorace', 'automobile racing', 'automobile race', 'race car driver', 'autosports', 'racecar driver', 'autoracing', 'auto racing', 'racecars', 'race cars', 'racing car', 'automobile racer', 'auto race', 'car racing', 'racing driver', '🏎', 'car race', 'race car', 'racing cars', 'racecar', 'automotive racing']
# em=0: Every other club is either defunct or out of the League ['three', '3']
# em=0: General - "Cupid" was ranked #452 ['bertha franklin', 'i thank god', 'dale cook singer', 'sam cooke']
# em=0: fifteen-love ['let disambiguation', 'let']
# em=0: Spencer Gore ['fred j perry', 'fred perry', 'frederick john perry']
# em=0: General - Nadia Elena Comăneci ['nadia elena comăneci', 'comăneci', 'nadia comenici', 'nadia elena comaneci', 'comaneci nadia', 'comaneci', 'nadia comeneci', 'nadia comaneci', 'nadia comăneci']
# em=0: October 12, 1916 ['11 years and 302 days']
# em=0: General - Nicholas "Nick" Berry ['nick berry']
# em=0: Scottish ['sheep domestic', 'agnine', 'sheep sounds', '🐑', '🐏', 'domesticated sheep', 'persian lamb', 'ovis orientalis aries', 'ram sheep', 'domestic sheep', 'ovine', 'sheep description', 'domestic ewe', 'domestic ram', 'yorkshire leicester', 'ovis aries', 'sheeps', 'feral sheep', 'yowe', 'sheep', 'bleat']
# em=0: Paris ['lenkija', 'poleland', 'iso 3166 1 pl', 'po land', 'pologne', 'country poland', 'polska', 'pole land', 'ploand', 'polland', 'fourth poland', 'polskor', 'rzeczpospolita polska', 'polish state', 'pols land', 'bastarnia', 'etymology of poland', 'poland', 'polnd', 'architecture of poland', 'polija', 'republic of poland', 'poleand']
# em=0: AB and O ['🄾', 'ℴ', 'o letter', '🅞', 'o', 'ⓞ', '⒪', '🄞', 'ｏ']
# ...
# em=0: Mikhail Kasyanov ['vladimer putin', 'president putin', 'владимир путин', 'vladimir vladimirovich putin', 'vlad putin', 'political strongman of russia', 'puttin', 'valdimir v putin', 'vladimir puttin', 'влади́мир влади́мирович пу́тин', 'vladmir putin', 'vlad puttin', 'vlad vlad putin', 'vladimir vladimirovic putin', 'wladimir puttin', 'путин', 'wladimir putin', 'vladimir poutine', 'vladimir putin', 'v v putin', 'uladzimir putin', 'vladimir spiridonovich putin', 'putinland', 'vladimir vladimirovič putin', 'vladamir putin', 'v putin', 'putin', 'putin vladimir', 'putin 2 0', 'vladimir v putin', 'vvp', 'putey pute', 'tsar putin', 'пу́тин', 'vlad vladimirovich putin', 'vladimir putin quotes', 'владимир владимирович путин', 'в путин', 'путин владимир владимирович']
# em=0: American Freighter ['southwest airlines cargo', 'southwestair', 'southwest airlines vacations', 'southwestvacations com', 'southwest airlines flight 519', 'wnco com', 'southwest airtran merger', 'southwestvacaciones com', 'southwest airlines – airtran airways merger', 'southwest com', 'southwest airlines home gate', 'blogsouthwest com', 'southwest', 'southwest airlines company', 'southwest airlines', 'iflyswa', 'southwest air', 'southwest airlines co', 'southwest vacations', 'southwest airline', 'iflyswa com', 'southwest airlines flight 411', 'southwest airlines flight 345', 'wanna get away 3f', 'southwestairlines', 'setlovefree com', 'southwest airlines corporation', 'redbellyradio', 'southwest airlines airtran airways merger', 'swamedia com', 'red belly radio', 'southwest airlines flight 1927', '1 800 i fly swa', 'south west airlines', 'rapid rewards', 'swabiz', 'southwest airlines inc', 'nuts about southwest']
# em=0: Uncle Sam" meaning Wilson. Troy has since claimed to be the historical home of Uncle Sam ['i want you for u s army', 'uncle sam wants you recruitment poster', 'baba sam', 'uncle sam wants you', 'uncle sam']
# em=0: Challenge of the Super Friends ['hall of justice']
# em=0: group or solo ['cappella', 'recorded cappella review board', 'capella music', 'acappela', 'capela', 'cappellas', 'cappela', 'arcapella', 'acappella', 'accapella', 'acapella', 'capella', 'in church style', 'contemporary cappella', 'unaccompanied']
# em=0: radio receivers ['air search radar', 'radars', 'radio detection and ranging', 'centimetric radar', 'radar communication', 'radar system', 'radar station', 'radar homing and warning', 'microwave radar', 'radar distance measurement', 'radio detecting and ranging', 'radar', 'radar equation', 'airport radar', 'radar illumination']
# em=0: Warrenton ['langley disambiguation', 'langly', 'langley']
# em=0: Dorset Lane ['muffin man']
# em=0: American cheese, pickles, and onions ['maharaja mac', 'two all beef patties special sauce lettuce cheese pickles onions on sesame seed bun', 'big mac sauce', 'baby mac', 'monster mac', 'gotbot com', 'big mac® sauce', 'big mac r sauce', 'macsauce', 'big macs', 'bigmac', 'big mac slogan', 'special sauce', 'twoallbeefpattiesspecialsaucelettucecheesepicklesonionsonasesameseedbun', 'big mac', 'mega mac', 'special sauce mcdonald s', 'gofbot com']
# em=0: Ferrum ['edible silver', 'atcvet code qd08al30', 'timcanpi', 'silver element', 'silver', 'argentical', 'argentically', 'silverness', 'element xlvii', 'atc code d08al30', 'native silver', 'e174', 'silver metallurgy', 'silver mounted', 'silvern', 'silverily', '7440 22 4', 'element 47', 'argentic', 'silver processing', 'silver metal', 'silvermounted', 'silver compounds', 'silver ions', 'ag', 'argentate', 'argentum', 'silveriness', '🜛', 'silverly', 'argentous']
# em=0: black volcanic rocks ['hoover dam naming controversy', 'environmental impact of hoover dam', 'boulder canyon project act', 'hoover power plant', 'hoover dam', 'hooverdam', 'boulder canyon project', 'boulder dam', 'hoover damn']
# em=0: American Experience ['nova and supernova', 'rne', 'nova', 'novas', 'classical nova', 'helium nova', 'stellar surface fusion', 'recurrent nova', 'cne', 'recurring nova']
# em=0: Guerriere ['uss constitution 1797', 'usf constitution', 'uss constitution ix 21', 'ship constitution', 'u s s constitution', 'old constitution', 'uss old constitution', 'constitution vessel', 'uss constitution']
# em=0: Grand Canyon National Park ['north rim', 'great canyon', 'grand canyon park act of 1919', 'ongtupqa', 'grand canyon of colorado river', 'south rim', 'north rim of grand canyon', 'grand canynon', 'great colorado canyon', 'colorado canyon', 'grand canyon az', 'grand canyon', 'canon of colorado', 'grand canyon of colorado', 'lipan point', 'grand canyon arizona', 'grand canyon ariz']
# em=0: county-exec hopefuls ['king county executive']
# em=0: Parliament-Funkadelic ['parlament', 'parliamnet', 'parliarment', 'parliment', 'parlaiment', 'cabinet parliamentary', 'parliamentary government', 'national parliaments', 'national parliament', 'parliaments of europe', 'parliaments', 'parliament']
# em=0: Standard Oil Company ['standards disambiguation', 'standards', 'standard newspaper', 'standard', 'standards album', 'standard disambiguation', 'standard design']
# em=0: Presidents North Dakota ['t ros', 'cowboy president', 'theodore roosavelt', 'trust buster', 'president theodore roosevelt', 'teddy roosvelt', 'teddy rosevelt', 't roosevelt', 'roosevelt theodore', 'feddy roosevelt', 'cowboy of dakotas', 'teddy rose', '26th president of united states', 'teddy roosevelt foreign policy', 'teddy roose', 'teodoro roosevelt', 'theodore roosevelt', 'theodor roosevelt', 't roosevelt administration', 'teddy roosevelt']
# em=0: Glory Road ['robert anson heinlein', 'robert hienlien', 'robertheinlein', 'anson macdonald', 'dean of science fiction', 'robert anson macdonald heinlein', 'robert henlein', 'robert heinlein on metaphysics', 'robert heinlin', 'robert heinleim', 'caleb saunders', 'simon york', 'robert heinlein robert heinlein on metaphysics', 'patrick henry league', 'heinlein society', 'lyle monroe', 'robert heilein', 'ishtar book character', 'john riverside', 'robert heinlen', 'heinleinian', 'heinlin', 'robert heinlein']
# em=0: Cluedo ['weegie board', 'ouija board', 'ouiji', 'ouija boards', 'weegee board', 'talking board', 'oija board', 'quija board', 'ouja boards', 'weega', 'ouiji board', 'ouija planchette', 'weejee', 'ouija', 'ouija board criticism', 'talking boards', 'magical talking beard', 'oujia board', 'weejuh', 'spirit board']
# em=0: Penthouse Forum ['penthouse', 'penthouse disambiguation', 'pent house']
# em=0: fixed-blade fighting knife ['long knife', 'knife', 'sheath knives', 'fish knife', 'cable sheath splitting knife', 'ansall', 'knifes', 'knives', 'knive']
# em=0: Apu Nahasapeemapetilo ['quickie mart', 'kwikee mart', 'kwik e mart', 'freak e mart', 'kwikemart', 'quick e mart']
# em=0: two ['twelve', '12']
# em=0: General ['furry arms hotel', 'king banishes letter p', 'elmo noske', 'sesame street play group', 'sesame street film', 'sesame streets', 'seseme street', 'visit to sesame street hospital', 'sesamstreet', 'sesame street season 1', 'gloria globe', 'annual sesame street cookie baking contest', 'furry arms', 'how crayons are made', 'sesame street season 2', 'sesamestreet', 'sesame st', 'sesame street universe', 'sesame street', 'visit to sesame street museum', 'sesame street episodes', 'list of sesame street episodes']
# em=0: Rumpletini ['apple martini', 'appletini']
# em=0: water bodies ['🐥', 'modern dinosaurs', 'avafauna', 'pet bird', 'baby birds', 'living dinosaurs in australasia', 'flying bird', 'bird breeding', 'nestlings', 'ornis', 'avialian', 'neornithes', '🐦', 'aves', 'roosting', 'nestling', 'class aves', 'modern bird', '🐤', 'avian proteins', 'ornithes', 'chick bird', 'avian reproduction', 'living sauropods in africa', 'avialan', 'roost site', 'surviving dinosaurs', 'birds mating', 'avifauna', 'avian dinosaur', '🐣', 'living dinosaurs in oceania', 'living sauropods', 'neornithine', 'bird', 'modern birds', 'birdness', 'chick guard stage', 'avialians', 'birds', 'bird reproduction', 'avians', 'aviala']
# em=0: Griffin Peterson ['cleveland brown', 'cleveland orenthal brown', 'cleveland brown sr', 'cleveland jr', 'cleveland sr', 'cleveland junior', 'cleveland family guy', 'cleveland s deli', 'brown family']
# em=0: three hours ['40 time', 'forty time', '40 seconds']
# em=0: cigars, and pipes ['cocaine abuse', 'columbian marching powder', 'ye yo', 'gaggas', 'effects of cocaine', 'yeyo', 'methylbenzoylecgonine', 'crack heads', 'atc code n01bc01', 'synthetic cocaine', 'crack cocaine', 'freebase cocaine', 'cocaine hydro chloride', 'atc code s01ha01', 'cocaine related disorders', 'farlopa', 'methyl benzoylecgonine', 'crack overdose', 'atc code r02ad03', 'cocaine hcl', 'benzoylmethylecgonine', 'coke drug', 'kilogram of cocaine', 'atcvet code qr02ad03', 'cocaine hydrochloride', 'benzoyl methyl ecgonine', 'cocaine', 'cocoaine', 'atcvet code qs01ha01', 'crackpipe', 'cocaine trafficking', 'atcvet code qn01bc01', 'cocain', 'cocaine trade', 'prohibition of cocaine in united states', 'llello', 'powdered cocaine', 'bolivian marching powder', 'nose candy', 'atcvet code qs02da02', 'atc code s02da02', 'erythroxyline']
# em=0: chlorophylls  - Anthocyanins ['chlorophil', 'leafgreen', 'c55h72o5n4mg', 'chlorophyllous', 'c35h30o5n4mg', 'chlorophyll', 'clorophyl', 'cholorophyl', 'cholorophyll', 'chlorophylls', 'leaf green', 'chorophyll', 'e140 e number', 'c54h70o6n4mg', 'c35h28o5n4mg', 'chlorophyllose', 'clorofill', 'c55h70o6n4mg', 'chlorafil', 'chlorophyl']
# em=0: the plate which is the lower belly ['diaphragm', 'diafragm', 'diaphragm disambiguation', 'diapragm', 'diafram', 'diaphram']
# em=0: ISIS ['toxophilite', 'archery', 'bowmanship', 'endong', 'bowmen', 'archer comics', 'archeress', 'archers', 'primitive archery', 'toxopholite', 'archerie', 'national archery in schools program', 'indoor archery', 'para archery', 'butt shooting', 'toxophily', 'archer', 'anchor point archery', 'archers disambiguation', 'archery range', 'villavar tamils', 'paralympic archery']
# em=0: Pac-Man ['blinky', 'blinky disambiguation']
# em=0: Haigha in Through the Looking-Glass) is a character most famous for appearing in the tea party scene in Lewis Carroll ['mad hatter', 'why is raven like writing desk 3f', '10 6', 'hatter alice s adventures in wonderland', 'hatter', 'in this style 10 6', 'madhatter']
# em=0: Bush ['bush junior', 'bushian', 'george w budh', 'g dub', 'baby bush', 'bush ii', 'george w bush', 'gorge w bush', 'g walker bush', 'jorge w bush', 'george w bush jr', 'us president george w bush', 'george w bush street', 'goerge w bush', 'george bush junior', 'georgewbush', 'gw bush', 'george walker bush', '43rd pesident of united states', 'george w bush 43rd president of united states', 'george w buah', 'george bush 2000', 'international perception of george w bush', 'dubya bush', 'george bush jr', 'george w bush painter', 'george w', 'junior bush', 'bush george w', 'dubyuh', 'g w bush', 'w bush', 'george dubya bush', 'george bush ii', 'george bush 2', 'dubya', 'bushists', 'president bush 2000', '2004 republican presidential nominee', 'religious faith of george w bush', 'president bush 43', 'former president george w bush', 'bush 43', '43rd president of united states', 'g w b', 'george w bussh', 'bush jr', 'george wаlker bush', 'president george walker bush', 'bush younger', 'george bush 43rd u s president', 'george bush 43', 'george younger', '2000 republican presidential nominee', 'geroge w bush', 'president george w bush']
# em=0: the Declaration of Independence ['of people by people for people', 'gettysburg oration', 'lincoln s address', 'lincoln address', 'gettysburg address', 'lincoln s gettysburg address', 'president lincolns gettysburg address', 'four score and seven', 'address of gettysburg', 'gettysburg speech', 'four score and seven years ago', 'gettysburg adress', 'gettysberg address']
# em=0: Mercury ['planet neptune', '♆', 'neptune s weather', 'neptune', 'neptune s', 'scooter neptune', 'astronomy neptune', 'planet exterior to uranus', 'neptunus planet', 'neptune planet', 'eighth planet', 'magnetosphere of neptune', 'neptune s atmosphere', 'sol iix', 'le verrier s planet', 'neptuno planet', 'weather of neptune', 'neptune astronomy', 'neptune blue ocean planet', 'sun i', 'sol 8', '8th planet', 'sol viii', 'atmosphere of neptune']
# em=0: Howard Friedman ['gregory miso sarum', 'tom ashe', 't tinker', 'simon wagstaff esq', 'jonathan swift', 'student of astrology', 'johnathon swift', 'gregory misosarum', 't n philomath', 'm flor o squarr', 'jonathon swift', 'cadenus', 'm b drapier', 'swiftian', 'jonathin swift', 'dr andrew tripe', 't h philomath', 'johnathan swift', 'verses on death of dr swift', 's p m', 'sieur de baudrier', 'enemy of peace', 'johathan swift', 'dean swift']
# em=0: suture ['cartilage or cartilages', 'cartilaginous', 'cartilage disorders', 'elastic fibrocartilage', 'cartilage', 'cartilege', 'cartilages', 'chondric', 'chondral', 'fibro cartilage', 'cartillage', 'cartilage diseases', 'cartilago', 'soft bone', 'articular cartilage']
# em=0: King Atlas of Mauretania ['atlas book', 'atlases', 'atlas geography', 'atlas cartography', 'atlas']
# em=0: Presidential libraries ['jimmie carter junior', 'jimmie carter jr', 'james earl carter jr', 'carter jimmie', 'jimi carter', 'james earl carter junior', 'james earl 22jimmie 22 carter junior', 'james e carter jr', 'james earle carter', 'jimmy carter junior', 'james earl 22jimmy 22 carter', 'james e carter', 'why not best', 'james earl 22jimmy 22 carter junior', 'jimmy carter jr', 'jimmy earl carter', 'carter james earl', 'jimmy carter', 'james 22jimmy 22 carter', 'james earl carter', 'james earl jimmy carter', 'jimmie carter', 'carter james earl 22jimmy 22', 'carter james earl 22jimmie 22', 'james earl 22jimmie 22 carter jr', 'carter jimmy', 'james earl 22jimmy 22 carter jr', 'president carter', 'president jimmy carter', '39th president of united states', 'james carter jr', 'jimmy e carter']
# em=0: Dry Cat Food ['meow mix', 'meowmix', 'meow mix theme', 'meow mix cat', 'singing cat', 'meow mix cat food', 'alley cat cat food']
# em=0: Geoffrey the Giraffe ['geoffroy', 'geoffrey disambiguation', 'geoff', 'geoffrey']
# em=0: Canada ['over falls in barrel', 'cataratas del niagara', 'niagra falls', 'hell of waters', 'cataratas del niágara', 'over niagara falls', 'niagara falls n y and ont', 'niagara falls', 'niagarafalls', 'daredevils of niagara falls', 'roger woodward niagara falls', 'niagara falls power generation']
# em=0: Coca-Cola Icecek ['minute maid es', 'minute maid company', 'minutemaid co uk', 'minute maid de', 'minutemaid co kr', 'minute maid', 'minutemaid com mx']
# em=0: MSM Records ['gloria estefan and miami sound machine', 'gloria estafan', 'estefan', 'gloria estéfan', 'gloria estefan discography', 'gloria estefan', 'gloria estefan miami sound machine', 'gloria maria estefan', 'gloria m estefan', 'gloria esteban']
# em=0: militia ['national guard', 'national gaurd', 'guardia nacional', 'national guard disambiguation']
# em=0: Felix Bernard ['orangeishblack', 'orangeish black', 'brownest', 'blackish oranges', 'brownly', 'orangish blacks', 'orangish black', 'brown', 'black orange', 'blackishoranges', 'brown color', 'orangeblack', 'dark brown', 'brownness', 'orangishblacks', 'blackishorange', 'black oranges', 'orange black', 'brownish', 'brownishness', 'blackish orange', 'orangishblack', 'list of terms associated with color brown', 'brownishly', 'orange blacks', 'pale sandy brown', 'reddish brown', 'blackorange', 'blackoranges', 'orangeishblacks', 'light brown', 'brown colour', 'orangeish blacks', 'pullman brown', 'orangeblacks']
# em=0: Back-yard games can be played to any number of points that is agreed upon, but are usually to 21 points, win by 2.  In most sanctioned tournaments the handicapped divisions pitch 50 shoe games ['horseshoe pitching', 'horse shoes', 'horseshoe throwing', 'horseshoe pit', 'horseshoes game', 'horseshoes']

# %%
print(eval_dict)
# Out:
# {'exact_match': 32.51595145752533, 'f1': 41.96009135655252, 'common': 7992, 'denominator': 7993, 'pred_len': 7992, 'gold_len': 7993}
